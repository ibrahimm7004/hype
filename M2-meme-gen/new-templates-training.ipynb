# %%
import requests
import os

# Target folder (your local path)
save_dir = r"C:\Users\hp\Desktop\fyp\mvp\M2-meme-gen\meme-templates-updated"
os.makedirs(save_dir, exist_ok=True)

# Fetch meme templates from Imgflip
print("Fetching meme templates...")
response = requests.get("https://api.imgflip.com/get_memes")
memes = response.json().get("data", {}).get("memes", [])

print(f"Found {len(memes)} meme templates.")

# Download each template
for meme in memes:
    name = meme["name"].replace(" ", "_").replace("/", "_").replace("\\", "_")
    url = meme["url"]
    ext = os.path.splitext(url)[-1] or ".jpg"  # default extension
    filename = os.path.join(save_dir, f"{name}{ext}")

    try:
        img_data = requests.get(url, timeout=10).content
        with open(filename, "wb") as f:
            f.write(img_data)
        print(f"✅ Downloaded: {name}")
    except Exception as e:
        print(f"❌ Failed to download {name}: {e}")

print("Done.")
# Out:
# Fetching meme templates...
# Found 100 meme templates.
# ✅ Downloaded: Drake_Hotline_Bling
# ✅ Downloaded: Two_Buttons
# ✅ Downloaded: Distracted_Boyfriend
# ✅ Downloaded: UNO_Draw_25_Cards
# ✅ Downloaded: Bernie_I_Am_Once_Again_Asking_For_Your_Support
# ✅ Downloaded: Left_Exit_12_Off_Ramp
# ✅ Downloaded: Running_Away_Balloon
# ✅ Downloaded: Disaster_Girl
# ✅ Downloaded: Gru's_Plan
# ✅ Downloaded: Waiting_Skeleton
# ✅ Downloaded: Always_Has_Been
# ✅ Downloaded: Change_My_Mind
# ✅ Downloaded: Sad_Pablo_Escobar
# ✅ Downloaded: Epic_Handshake
# ✅ Downloaded: Batman_Slapping_Robin
# ✅ Downloaded: Anakin_Padme_4_Panel
# ✅ Downloaded: Marked_Safe_From
# ✅ Downloaded: Woman_Yelling_At_Cat
# ✅ Downloaded: X,_X_Everywhere
# ✅ Downloaded: Buff_Doge_vs._Cheems
# ✅ Downloaded: Mocking_Spongebob
# ✅ Downloaded: Trade_Offer
# ✅ Downloaded: Expanding_Brain
# ✅ Downloaded: Bike_Fall
# ✅ Downloaded: I_Bet_He's_Thinking_About_Other_Women
# ✅ Downloaded: Tuxedo_Winnie_The_Pooh
# ✅ Downloaded: One_Does_Not_Simply
# ✅ Downloaded: Is_This_A_Pigeon
# ✅ Downloaded: They're_The_Same_Picture
# ✅ Downloaded: Bernie_Sanders_Once_Again_Asking
# ✅ Downloaded: Y'all_Got_Any_More_Of_That
# ✅ Downloaded: Monkey_Puppet
# ✅ Downloaded: This_Is_Fine
# ✅ Downloaded: Success_Kid
# ✅ Downloaded: Ancient_Aliens
# ✅ Downloaded: Hide_the_Pain_Harold
# ✅ Downloaded: Trump_Bill_Signing
# ✅ Downloaded: Mother_Ignoring_Kid_Drowning_In_A_Pool
# ✅ Downloaded: Boardroom_Meeting_Suggestion
# ✅ Downloaded: This_Is_Where_I'd_Put_My_Trophy_If_I_Had_One
# ✅ Downloaded: Oprah_You_Get_A
# ✅ Downloaded: Squid_Game
# ✅ Downloaded: Sleeping_Shaq
# ✅ Downloaded: Clown_Applying_Makeup
# ✅ Downloaded: You_Guys_are_Getting_Paid
# ✅ Downloaded: Megamind_peeking
# ✅ Downloaded: 0_days_without_(Lenny,_Simpsons)
# ✅ Downloaded: Squidward_window
# ✅ Downloaded: Blank_Nut_Button
# ✅ Downloaded: where_monkey
# ✅ Downloaded: Flex_Tape
# ✅ Downloaded: Roll_Safe_Think_About_It
# ✅ Downloaded: Surprised_Pikachu
# ✅ Downloaded: They_don't_know
# ✅ Downloaded: Whisper_and_Goosebumps
# ✅ Downloaded: Who_Killed_Hannibal
# ✅ Downloaded: Leonardo_Dicaprio_Cheers
# ✅ Downloaded: Evil_Kermit
# ✅ Downloaded: Pawn_Stars_Best_I_Can_Do
# ✅ Downloaded: Bell_Curve
# ✅ Downloaded: Two_guys_on_a_bus
# ✅ Downloaded: Soldier_protecting_sleeping_child
# ✅ Downloaded: AJ_Styles_&_Undertaker
# ✅ Downloaded: Grant_Gustin_over_grave
# ✅ Downloaded: Panik_Kalm_Panik
# ✅ Downloaded: Inhaling_Seagull
# ✅ Downloaded: Grandma_Finds_The_Internet
# ✅ Downloaded: Spider_Man_Triple
# ✅ Downloaded: Laughing_Leo
# ✅ Downloaded: Types_of_Headaches_meme
# ✅ Downloaded: A_train_hitting_a_school_bus
# ✅ Downloaded: Star_Wars_Yoda
# ✅ Downloaded: Futurama_Fry
# ✅ Downloaded: Disappointed_Black_Guy
# ✅ Downloaded: Three-headed_Dragon
# ✅ Downloaded: All_My_Homies_Hate
# ✅ Downloaded: Friendship_ended
# ✅ Downloaded: The_Rock_Driving
# ✅ Downloaded: The_Scroll_Of_Truth
# ✅ Downloaded: Third_World_Skeptical_Kid
# ✅ Downloaded: American_Chopper_Argument
# ✅ Downloaded: Domino_Effect
# ✅ Downloaded: is_this_butterfly
# ✅ Downloaded: Anime_Girl_Hiding_from_Terminator
# ✅ Downloaded: Megamind_no_bitches
# ✅ Downloaded: Gus_Fring_we_are_not_the_same
# ✅ Downloaded: Look_At_Me
# ✅ Downloaded: Spongebob_Ight_Imma_Head_Out
# ✅ Downloaded: Finding_Neverland
# ✅ Downloaded: spiderman_pointing_at_spiderman
# ✅ Downloaded: George_Bush_9_11
# ✅ Downloaded: The_Most_Interesting_Man_In_The_World
# ✅ Downloaded: Unsettled_Tom
# ✅ Downloaded: c'mon_do_something
# ✅ Downloaded: Two_Paths
# ✅ Downloaded: whe_i'm_in_a_competition_and_my_opponent_is
# ✅ Downloaded: say_the_line_bart!_simpsons
# ✅ Downloaded: Charlie_Conspiracy_(Always_Sunny_in_Philidelphia)
# ✅ Downloaded: patrick_to_do_list_actually_blank
# ✅ Downloaded: Scooby_doo_mask_reveal
# Done.

# %%
import requests
from bs4 import BeautifulSoup
import os
import time

# Set your save directory
save_dir = r"C:\Users\hp\Desktop\fyp\mvp\M2-meme-gen\meme-templates-updated-2"
os.makedirs(save_dir, exist_ok=True)

# Base URL for meme templates
base_url = "https://imgflip.com/memetemplates"

# Sanitize filenames
def sanitize_filename(name):
    return "".join(c if c.isalnum() or c in (' ', '_') else '_' for c in name).strip().replace(' ', '_')

def scrape_imgflip_templates(max_templates=1000):
    downloaded = 0
    page = 1
    seen_urls = set()

    while downloaded < max_templates:
        url = f"{base_url}?page={page}"
        print(f"🔄 Scraping page {page}...")

        res = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        if res.status_code != 200:
            print(f"❌ Failed to load page {page}")
            break

        soup = BeautifulSoup(res.text, "html.parser")
        boxes = soup.select("div.mt-box")

        if not boxes:
            print("✅ No more templates found.")
            break

        for box in boxes:
            if downloaded >= max_templates:
                break

            # Extract name
            title_tag = box.select_one("h3.mt-title a")
            if not title_tag:
                continue
            name = title_tag.text.strip()

            # Extract image URL
            img_tag = box.select_one("img")
            if not img_tag or "src" not in img_tag.attrs:
                continue
            img_url = img_tag["src"]
            if img_url.startswith("//"):
                img_url = "https:" + img_url

            # Skip duplicates
            if img_url in seen_urls:
                continue
            seen_urls.add(img_url)

            filename = os.path.join(save_dir, sanitize_filename(name) + ".jpg")
            if os.path.exists(filename):
                continue

            try:
                img_data = requests.get(img_url, timeout=10).content
                with open(filename, "wb") as f:
                    f.write(img_data)
                downloaded += 1
                print(f"✅ ({downloaded}) {name}")
            except Exception as e:
                print(f"❌ Failed to download {name}: {e}")

        page += 1
        time.sleep(1)  # Be polite

    print(f"\n🎉 Finished! Downloaded {downloaded} meme templates.")

# Run the scraper
scrape_imgflip_templates(max_templates=1000)
# Out:
# 🔄 Scraping page 1...
# ✅ (1) Drake Hotline Bling
# ✅ (2) Two Buttons
# ✅ (3) Distracted Boyfriend
# ✅ (4) UNO Draw 25 Cards
# ✅ (5) Bernie I Am Once Again Asking For Your Support
# ✅ (6) Left Exit 12 Off Ramp
# ✅ (7) Running Away Balloon
# ✅ (8) Disaster Girl
# ✅ (9) Gru's Plan
# ✅ (10) Waiting Skeleton
# ✅ (11) Always Has Been
# ✅ (12) Sad Pablo Escobar
# ✅ (13) Change My Mind
# ✅ (14) Epic Handshake
# ✅ (15) Batman Slapping Robin
# ✅ (16) Anakin Padme 4 Panel
# ✅ (17) Marked Safe From
# ✅ (18) Woman Yelling At Cat
# ✅ (19) X, X Everywhere
# ✅ (20) Buff Doge vs. Cheems
# ✅ (21) Mocking Spongebob
# ✅ (22) Trade Offer
# ✅ (23) Bike Fall
# ✅ (24) Expanding Brain
# ✅ (25) I Bet He's Thinking About Other Women
# ✅ (26) Tuxedo Winnie The Pooh
# ✅ (27) One Does Not Simply
# ✅ (28) Is This A Pigeon
# ✅ (29) They're The Same Picture
# ✅ (30) Bernie Sanders Once Again Asking
# ✅ (31) Monkey Puppet
# ✅ (32) Y'all Got Any More Of That
# ✅ (33) This Is Fine
# ✅ (34) Success Kid
# ✅ (35) Ancient Aliens
# ✅ (36) Hide the Pain Harold
# ✅ (37) Mother Ignoring Kid Drowning In A Pool
# ✅ (38) Trump Bill Signing
# ✅ (39) Boardroom Meeting Suggestion
# ✅ (40) This Is Where I'd Put My Trophy If I Had One
# 🔄 Scraping page 2...
# ✅ (41) Oprah You Get A
# ✅ (42) Squid Game
# ✅ (43) Sleeping Shaq
# ✅ (44) Clown Applying Makeup
# ✅ (45) You Guys are Getting Paid
# ✅ (46) Megamind peeking
# ✅ (47) 0 days without (Lenny, Simpsons)
# ✅ (48) Squidward window
# ✅ (49) Blank Nut Button
# ✅ (50) where monkey
# ✅ (51) Flex Tape
# ✅ (52) Roll Safe Think About It
# ✅ (53) Surprised Pikachu
# ✅ (54) They don't know
# ✅ (55) Whisper and Goosebumps
# ✅ (56) Who Killed Hannibal
# ✅ (57) Evil Kermit
# ✅ (58) Bell Curve
# ✅ (59) Pawn Stars Best I Can Do
# ✅ (60) Two guys on a bus
# ✅ (61) Soldier protecting sleeping child
# ✅ (62) AJ Styles & Undertaker
# ✅ (63) Inhaling Seagull
# ✅ (64) Panik Kalm Panik
# ✅ (65) Leonardo Dicaprio Cheers
# ✅ (66) Grant Gustin over grave
# ✅ (67) Spider Man Triple
# ✅ (68) Laughing Leo
# ✅ (69) Types of Headaches meme
# ✅ (70) Grandma Finds The Internet
# ✅ (71) A train hitting a school bus
# ✅ (72) Disappointed Black Guy
# ✅ (73) Star Wars Yoda
# ✅ (74) Futurama Fry
# ✅ (75) All My Homies Hate
# ✅ (76) Three-headed Dragon
# ✅ (77) Friendship ended
# ✅ (78) The Rock Driving
# ✅ (79) The Scroll Of Truth
# ✅ (80) Third World Skeptical Kid
# 🔄 Scraping page 3...
# ✅ (81) Domino Effect
# ✅ (82) is this butterfly
# ✅ (83) Anime Girl Hiding from Terminator
# ✅ (84) Megamind no bitches
# ✅ (85) Gus Fring we are not the same
# ✅ (86) Look At Me
# ✅ (87) Spongebob Ight Imma Head Out
# ✅ (88) Finding Neverland
# ✅ (89) spiderman pointing at spiderman
# ✅ (90) George Bush 9/11
# ✅ (91) The Most Interesting Man In The World
# ✅ (92) Unsettled Tom
# ✅ (93) c'mon do something
# ✅ (94) Two Paths
# ✅ (95) whe i'm in a competition and my opponent is
# ✅ (96) say the line bart! simpsons
# ✅ (97) patrick to do list actually blank
# ✅ (98) Charlie Conspiracy (Always Sunny in Philidelphia)
# ✅ (99) Scooby doo mask reveal
# ✅ (100) What Gives People Feelings of Power
# ✅ (101) No - Yes
# ✅ (102) Bugs bunny communist
# ✅ (103) Goose Chase
# ✅ (104) Grim Reaper Knocking Door
# ✅ (105) obama medal
# ✅ (106) the office congratulations
# ✅ (107) i receive you receive
# ✅ (108) Drake Blank
# ✅ (109) undertaker
# ✅ (110) elmo cocaine
# ✅ (111) Disappearing kid gif
# ✅ (112) Wolverine Remember
# ✅ (113) Borat 2 Tonight Queen??
# ✅ (114) Sure grandma let's get you to bed
# ✅ (115) Moe throws Barney
# ✅ (116) Don't make me tap the sign
# ✅ (117) Yo Dawg Heard You
# ✅ (118) shoebody summoning
# ✅ (119) spongebob rainbow
# 🔄 Scraping page 4...
# ✅ (120) Kombucha Girl
# ✅ (121) Bad Luck Brian
# ✅ (122) You know, I'm something of a scientist myself
# ✅ (123) I'm The Captain Now
# ✅ (124) damn got hands
# ✅ (125) The future world if
# ✅ (126) Live reaction
# ✅ (127) I Should Buy A Boat Cat
# ✅ (128) talking to wall
# ✅ (129) Car Salesman Slaps Roof Of Car
# ✅ (130) Empty Stonks
# ✅ (131) Here it comes
# ✅ (132) Surprised Koala
# ✅ (133) Both Buttons Pressed
# ✅ (134) Black guy hiding behind tree
# ✅ (135) Spongebob Burning Paper
# ✅ (136) Man Holding Cardboard Sign
# ✅ (137) Mr. McMahon reaction
# ✅ (138) blank invincible title card
# ✅ (139) I don't want to play with you anymore
# ✅ (140) Never ask a woman her age
# ✅ (141) Math lady/Confused lady
# ✅ (142) Afraid To Ask Andy
# ✅ (143) Blank White Template
# ✅ (144) Grumpy Cat
# ✅ (145) Community Fire Pizza Meme
# ✅ (146) Who wants to be a millionaire?
# ✅ (147) Skinner Out Of Touch
# ✅ (148) Hold fart
# ✅ (149) Soyboy Vs Yes Chad
# ✅ (150) Doge
# ✅ (151) Oh yeah! Oh no...
# ✅ (152) Gentlemen, it is with great pleasure to inform you that
# ✅ (153) Brain Before Sleep
# ✅ (154) kermit window
# ✅ (155) Chill guy
# ✅ (156) Simpsons so far
# ✅ (157) Mugatu So Hot Right Now
# ✅ (158) Absolute Cinema
# ✅ (159) triggerpaul
# 🔄 Scraping page 5...
# ✅ (160) Imagination Spongebob
# ✅ (161) Cat looks inside
# ✅ (162) Chef Skinner Reading a Letter
# ✅ (163) Uncle Sam
# ✅ (164) High five drown
# ✅ (165) Brace Yourselves X is Coming
# ✅ (166) First World Problems
# ✅ (167) A second plane has just hit
# ✅ (168) See Nobody Cares
# ✅ (169) blank red MAGA hat
# ✅ (170) Homer disappears into bush
# ✅ (171) For the better right blank
# ✅ (172) You know, I'm something of a _ myself
# ✅ (173) If those kids could read they'd be very upset
# ✅ (174) One girl five guys
# ✅ (175) Sad Hamster
# ✅ (176) death knocking at the door
# ✅ (177) hello human resources
# ✅ (178) Peter Griffin skin color chart race terrorist blank
# ✅ (179) Second Breakfast
# ✅ (180) Friendship ended with X, now Y is my best friend
# ✅ (181) Philosoraptor
# ✅ (182) Oprah You Get A Car Everybody Gets A Car
# ✅ (183) the office handshake
# ✅ (184) Wake Up Babe
# ✅ (185) Mr incredible mad
# ✅ (186) Horse Drawing
# ✅ (187) Milk carton
# ✅ (188) Drake No/Yes
# ✅ (189) Mr bean waiting
# ✅ (190) Doof If I had a Nickel
# ✅ (191) Yes Honey
# ✅ (192) Ol' Reliable
# ✅ (193) Teacher's Copy
# ✅ (194) Guy recording a fight
# ✅ (195) Shrek running
# ✅ (196) Satisfied Seal
# ✅ (197) dave chappelle
# ✅ (198) Smiling Cat
# 🔄 Scraping page 6...
# ✅ (199) Gru Gun
# ✅ (200) Homer Simpson's Back Fat
# ✅ (201) Steve Buscemi Fellow Kids
# ✅ (202) Y U No
# ✅ (203) Put It Somewhere Else Patrick
# ✅ (204) drowning kid + skeleton
# ✅ (205) family guy louis pills
# ✅ (206) Red pill blue pill
# ✅ (207) Keep Calm And Carry On Red
# ✅ (208) Illusion of free choice
# ✅ (209) Fernanfloo Dresses Up
# ✅ (210) Shut Up And Take My Money Fry
# ✅ (211) Rick and Carl
# ✅ (212) Too Damn High
# ✅ (213) Did you mean?
# ✅ (214) Overwatch Mercy Meme
# ✅ (215) Sad guy Happy guy bus
# ✅ (216) Why Can't You Just Be Normal
# ✅ (217) Vince McMahon Reaction w/Glowing Eyes
# ✅ (218) And Just Like That
# ✅ (219) Jason Momoa Henry Cavill Meme
# ✅ (220) Who Would Win?
# ✅ (221) They hated jesus because he told them the truth
# ✅ (222) batman signal
# ✅ (223) Spongebob Yelling
# ✅ (224) Pepperidge Farm Remembers
# ✅ (225) Are they in the room with us right now?
# ✅ (226) money smell
# ✅ (227) Pointing mirror guy
# ✅ (228) That's the neat part, you don't
# ✅ (229) Ben affleck smoking
# ✅ (230) Oprah 'You Get A Car'
# ✅ (231) Jim Halpert Explains
# ✅ (232) Big book small book
# ✅ (233) Woody and Buzz Lightyear Everywhere Widescreen
# ✅ (234) Success Kid Original
# ✅ (235) Squid Game (Season 1 vs Season 2)
# ✅ (236) Confused Monkey
# ✅ (237) Look What They Need To Mimic A Fraction Of Our Power
# 🔄 Scraping page 7...
# ✅ (238) Traumatized Mr. Incredible
# ✅ (239) FINALLY
# ✅ (240) Black Girl Wat
# ✅ (241) Welcome To The Internets
# ✅ (242) Happy dolphin rainbow
# ✅ (243) William Dafoe looking up
# ✅ (244) first time
# ✅ (245) Jack Sparrow Being Chased
# ✅ (246) Black White Arms
# ✅ (247) I See Dead People
# ✅ (248) Incoming call
# ✅ (249) Dinkleberg
# ✅ (250) Laughing Men In Suits
# ✅ (251) Buddy Christ
# ✅ (252) black guy stopping
# ✅ (253) I’m going to change the world. For the better right? Star Wars.
# ✅ (254) Bilbo - Why shouldn’t I keep it?
# ✅ (255) Matrix Morpheus
# ✅ (256) Spider Man Double
# ✅ (257) But That's None Of My Business
# ✅ (258) i don't always
# ✅ (259) Make your own meme
# ✅ (260) Inside you there are two wolves
# ✅ (261) Skeletor disturbing facts
# ✅ (262) drowning kid in the pool
# ✅ (263) Crying cat
# ✅ (264) Silence X, a Y is talking
# ✅ (265) Straight to Jail
# ✅ (266) Evil Toddler
# ✅ (267) Severance Outie Affirmation
# ✅ (268) X All The Y
# ✅ (269) Pedro Pascal crying
# ✅ (270) My body is machine
# ✅ (271) I am once again asking
# ✅ (272) Always you three
# ✅ (273) dog vs werewolf
# ✅ (274) Dr Evil Laser
# ✅ (275) Creepy Condescending Wonka
# ✅ (276) I believe in supremacy
# 🔄 Scraping page 8...
# ✅ (277) Aaaaand Its Gone
# ✅ (278) Guy in corner of party
# ✅ (279) i sleep real shit
# ✅ (280) Stupid dumb drooling puzzle
# ✅ (281) Anthony Adams Rubbing Hands
# ✅ (282) Cute Cat
# ✅ (283) fat man drinking from pipe
# ✅ (284) I fear no man
# ✅ (285) Marked Safe From Big
# ✅ (286) Happy / Shock
# ✅ (287) Jarvis,
# ✅ (288) Phoebe Joey
# ✅ (289) Don't You Squidward
# ✅ (290) elmo fire
# ✅ (291) Blank Starter Pack
# ✅ (292) walter white cooking
# ✅ (293) TOYSTORY EVERYWHERE
# ✅ (294) 20 minute adventure rick morty
# ✅ (295) Black background
# ✅ (296) Sparta Leonidas
# ✅ (297) Peace sign tombstone
# ✅ (298) astronaut meme always has been template
# ✅ (299) Confused John Travolta Pulp Fiction
# ✅ (300) Do all the things
# ✅ (301) This Is Brilliant But I Like This
# ✅ (302) Trojan Horse
# ✅ (303) Squidward pointing
# ✅ (304) Superior Royalty
# ✅ (305) This is Worthless
# ✅ (306) Giant vs man
# ✅ (307) Futurama Zero Days Since Last Blank
# ✅ (308) Assassination chain
# ✅ (309) PTSD Chihuahua
# ✅ (310) Hard To Swallow Pills
# ✅ (311) Disappointed Man
# ✅ (312) Predator Handshake
# ✅ (313) Buzz lightyear clones
# ✅ (314) math is math
# 🔄 Scraping page 9...
# ✅ (315) Good Fellas Hilarious
# ✅ (316) achievement unlocked
# ✅ (317) Wait, its all
# ✅ (318) First time?
# ✅ (319) Penguin pointing at shipping label
# ✅ (320) Average Fan vs Average Enjoyer
# ✅ (321) DW Sign Won't Stop Me Because I Can't Read
# ✅ (322) Captain Phillips - I'm The Captain Now
# ✅ (323) Lisa Simpson's Presentation
# ✅ (324) PAtrick, Smart Dumb
# ✅ (325) Aragorn Black Gate for Frodo
# ✅ (326) Dr Evil air quotes
# ✅ (327) Free
# ✅ (328) sweating bullets
# ✅ (329) Face You Make Robert Downey Jr
# ✅ (330) Pedro Pascal Nick Cage
# ✅ (331) You guys are getting paid template
# ✅ (332) floating boy chasing running boy
# ✅ (333) fast guy explaining
# ✅ (334) These Aren't The Droids You Were Looking For
# ✅ (335) Yhorm Dark Souls
# ✅ (336) Pink Guy vs Bane
# ✅ (337) I'll Just Wait Here
# ✅ (338) Cat newspaper
# ✅ (339) Army clown
# ✅ (340) Minion in dark forest
# ✅ (341) Xbox Achievement
# ✅ (342) Hulk Taco
# ✅ (343) 3 Spiderman Pointing
# ✅ (344) If nobody got me blank
# ✅ (345) Squidward chair
# ✅ (346) Dancing monkeys
# ✅ (347) orangutan interview
# ✅ (348) Soyjak Pointing
# ✅ (349) Darth Vader
# ✅ (350) Mel Gibson and Jesus Christ
# ✅ (351) society if
# ✅ (352) For Dummies
# 🔄 Scraping page 10...
# ✅ (353) Crying Hulk
# ✅ (354) milking the cow
# ✅ (355) Normal and dark mr.incredibles
# ✅ (356) I Bring a Sort of X Vibe to the Y
# ✅ (357) patrick not my wallet
# ✅ (358) Midwit memes
# ✅ (359) corporate wants you to find the difference
# ✅ (360) Dead Baby Voldemort / What Happened To Him
# ✅ (361) Weak vs Strong Spongebob
# ✅ (362) Charlie Day
# ✅ (363) Hypnotize
# ✅ (364) thanos what did it cost
# ✅ (365) OMG hi
# ✅ (366) Blank Wild Pokemon Appears
# ✅ (367) Narcos waiting
# ✅ (368) two castles
# ✅ (369) Yelling Beaver
# ✅ (370) Looks like meat's back on the menu, boys!
# ✅ (371) Victoria David Beckham Be Honest
# ✅ (372) No Take, Only Throw
# ✅ (373) Jarvis Template
# ✅ (374) Galaxy Brain (3 brains)
# ✅ (375) Kratos and my life is yours
# ✅ (376) Trump Executive Order 2025
# ✅ (377) You wouldn’t X a Y
# ✅ (378) John Cena confuses
# ✅ (379) Cuphead Flower
# ✅ (380) Giga Chad
# ✅ (381) Lord of the Rings Meat's back on the menu
# ✅ (382) Robotnik Button
# ✅ (383) Spiderman Glasses
# ✅ (384) 3rd Place Celebration
# ✅ (385) Oops! All Berries
# ✅ (386) Cars Passing Each Other
# ✅ (387) Stop Trying to Make Fetch Happen
# ✅ (388) Bro explaining
# ✅ (389) Farquaad Pointing
# 🔄 Scraping page 11...
# ✅ (390) 5 black guys and blonde
# ✅ (391) It ain't much, but it's honest work
# ✅ (392) Mom can we have
# ✅ (393) X but Y
# ✅ (394) Leonardo DiCaprio Pointing
# ✅ (395) Virgin vs Chad
# ✅ (396) Why is my sister's name Rose
# ✅ (397) Bad Pun Dog
# ✅ (398) Donald trump approves
# ✅ (399) Bateman walking
# ✅ (400) I think i might miss my wife (blank)
# ✅ (401) Leave Britney Alone
# ✅ (402) Winter Is Coming
# ✅ (403) Thousand Yard Stare
# ✅ (404) He's probably thinking about girls
# ✅ (405) Born Died Welcome Back
# ✅ (406) Big dog small dog
# ✅ (407) Man giving sword to larger man
# ✅ (408) Angela scared Dwight
# ✅ (409) Lion king yeet
# ✅ (410) Calculating meme
# ✅ (411) Laughing wolf
# ✅ (412) Big thumb guy
# ✅ (413) Arm wrestling meme template
# ✅ (414) Pretending To Be Happy, Hiding Crying Behind A Mask
# ✅ (415) man taking a stand in a town hall meeting
# ✅ (416) Bro Please Bro
# ✅ (417) cross eyed spongebob
# ✅ (418) Limmy waking up
# ✅ (419) let me in
# ✅ (420) disappearing
# ✅ (421) Gravestone
# ✅ (422) Stop giving me your toughest battles
# ✅ (423) Homer Simpson sleeping peacefully
# ✅ (424) Please sir may I have some more
# ✅ (425) Atlas holding Earth
# ✅ (426) Scared Cat
# ✅ (427) cnn breaking news template
# ✅ (428) even harder
# 🔄 Scraping page 12...
# ✅ (429) Oliver Twist Please Sir
# ✅ (430) okay grandpa let's get you to bed
# ✅ (431) Guy in the suit
# ✅ (432) My beloved
# ✅ (433) Rage Table Smash
# ✅ (434) That's my secret
# ✅ (435) Daring today, aren't we squidward
# ✅ (436) Who wants change
# ✅ (437) Riley Reid meme
# ✅ (438) NONONOWAITWAITWAIT
# ✅ (439) This is Fine (Blank)
# ✅ (440) Get In Loser
# ✅ (441) Marvel Civil War 1
# ✅ (442) Priest tempted by girl
# ✅ (443) Twilight Aro
# ✅ (444) iceberg
# ✅ (445) Vince McMahon Crying
# ✅ (446) What if i told you
# ✅ (447) Old man cup of coffee
# ✅ (448) Insane Peter
# ✅ (449) our
# ✅ (450) Me And The Boys
# ✅ (451) What a week huh
# ✅ (452) I heart…..
# ✅ (453) Donald Trump
# ✅ (454) I do ONE Push-Up
# ✅ (455) Why would they do this
# ✅ (456) Typing kitty
# ✅ (457) Guess I'll die
# ✅ (458) I wish all x a very y
# ✅ (459) Not sure if- fry
# ✅ (460) Strong dog vs weak dog
# ✅ (461) crying wojak vs chad
# ✅ (462) No Soup For You
# ✅ (463) What's My Purpose - Butter Robot
# ✅ (464) Best,Better, Blurst
# ✅ (465) 1984 Calendar
# ✅ (466) There is no war in ba sing se
# ✅ (467) Andy Dwyer Excited
# 🔄 Scraping page 13...
# ✅ (468) Dancin bois
# ✅ (469) Feel like pure shit
# ✅ (470) Happy Star Congratulations
# ✅ (471) Somehow, Palpatine returned.
# ✅ (472) spongebob stupid
# ✅ (473) You can't defeat me
# ✅ (474) I'm tired boss
# ✅ (475) Gentleman frog
# ✅ (476) Ew, i stepped in shit
# ✅ (477) cmon do something
# ✅ (478) Trump, Vance, and Zelensky
# ✅ (479) Blackjack and Hookers
# ✅ (480) Sweaty Speedrunner
# ✅ (481) Car drives off of cliff,(improved)
# ✅ (482) Spongebob looking out window
# ✅ (483) Think Mark, Think
# ✅ (484) black cat zoning out
# ✅ (485) moving giga chad
# ✅ (486) Show me on this doll
# ✅ (487) Maslow's Hierarchy of Needs
# ✅ (488) Shrek For Five Minutes
# ✅ (489) Geordi Drake
# ✅ (490) and I took that personally
# ✅ (491) the circle of life
# ✅ (492) Woman Shouting Knives
# ✅ (493) Patrick Dunk Meme
# ✅ (494) babe please
# ✅ (495) Blank T-Shirt
# ✅ (496) I don't think about you at all Mad Men
# ✅ (497) Fantasy Painting
# ✅ (498) soup nazi
# ✅ (499) Call an ambulance but not for me
# ✅ (500) NPC Meme
# ✅ (501) Pie Chart Meme
# ✅ (502) black guy pointing at head
# ✅ (503) Plague Doctor Gangsta's Paradise
# ✅ (504) Angry Man pointing at hand
# 🔄 Scraping page 14...
# ✅ (505) Simpsons Monkey Fight
# ✅ (506) shrek rizz
# ✅ (507) is calling you
# ✅ (508) Badass Skeleton
# ✅ (509) Man sucking suck banana
# ✅ (510) Worst day of my life
# ✅ (511) Why Can't I Hold All These Limes
# ✅ (512) F dinosaur
# ✅ (513) My child will
# ✅ (514) Beyoncé ?! Tiffany Pollard
# ✅ (515) Happy Wojak vs Depressed Wojak
# ✅ (516) Doctor Fate
# ✅ (517) I am going to create an environment that is so toxic (blank)
# ✅ (518) Sisyphus
# ✅ (519) Mr bean copying
# ✅ (520) It's been 84 years
# ✅ (521) Sweating Jordan Peele
# ✅ (522) where banana
# ✅ (523) Greedy Pipe Man
# ✅ (524) Now That’s What I Call
# ✅ (525) Funeral
# ✅ (526) Shocked black guy
# ✅ (527) side eye teddy
# ✅ (528) Fake search
# ✅ (529) willem dafoe looking up
# ✅ (530) Maybe i am a monster blank
# ✅ (531) if i had a nickel for everytime
# ✅ (532) Say it Again, Dexter
# ✅ (533) Sun Tzu
# ✅ (534) Peter Griffin running away
# ✅ (535) Where Banana (blank)
# ✅ (536) Sad wojak cycle
# ✅ (537) Futuristic Utopia
# ✅ (538) Protected Kevin Hart
# ✅ (539) Stop He's Already Dead
# ✅ (540) Me explaining to my mom
# ✅ (541) Black Box Meme
# ✅ (542) es de mi agrado informarles
# 🔄 Scraping page 15...
# ✅ (543) Burning House Girl
# ✅ (544) Surprised Joey
# ✅ (545) Adam Silver Get Ready To Learn Buddy
# ✅ (546) Tyrone Biggums The Addict
# ✅ (547) morpheus matrix blue pill red pill
# ✅ (548) Captain america elevator
# ✅ (549) Socially Awesome Awkward Penguin
# ✅ (550) Willy Wonka Blank
# ✅ (551) Bro visited his friend
# ✅ (552) Blank protest sign
# ✅ (553) Three dragons
# ✅ (554) I can has cheezburger cat
# ✅ (555) Knights of the Round Table
# ✅ (556) Children scared of rabbit
# ✅ (557) Crab Rave
# ✅ (558) Por que tan elegante homero
# ✅ (559) telltale will remember that
# ✅ (560) You're a wizard harry
# ✅ (561) Clown Makeup slander
# ✅ (562) Mahatma Gandhi Rocks
# ✅ (563) Travolta
# ✅ (564) huell money
# ✅ (565) smiling dolphin
# ✅ (566) Oh dear, dear gorgeus
# ✅ (567) captain america so you
# ✅ (568) A center for ants?
# ✅ (569) umbrella academy meme
# ✅ (570) No yes lady
# ✅ (571) Pepe the Frog
# ✅ (572) Prove me wrong
# ✅ (573) Virgin and Chad
# ✅ (574) Roblox Ban
# ✅ (575) the silent protector
# ✅ (576) party loner
# ✅ (577) Go Fund Me
# ✅ (578) Really? Right in front of my pancit?
# ✅ (579) I'm the dumbest man alive
# ✅ (580) Jim Halpert Pointing to Whiteboard
# ✅ (581) Body is a Machine
# 🔄 Scraping page 16...
# ✅ (582) Nemo Seagulls Mine
# ✅ (583) Judgemental Volturi
# ✅ (584) Am I The Only One Around Here
# ✅ (585) I don't care if you win, I just need X to lose
# ✅ (586) Chapelle crack
# ✅ (587) South Park Underpants Gnomes
# ✅ (588) Kramer, what's going on in there
# ✅ (589) Old man yells at cloud
# ✅ (590) Silence Crab
# ✅ (591) Nyan Cat
# ✅ (592) ralph wiggum
# ✅ (593) Thinking Black Guy
# ✅ (594) I Was Told There Would Be
# ✅ (595) Zoolander Stare TT
# ✅ (596) Youre going to make me
# ✅ (597) That's a paddlin'
# ✅ (598) Note passing
# ✅ (599) Aye, I Could Do That Blank
# ✅ (600) Normal Distribution meme
# ✅ (601) Will Smith punching Chris Rock
# ✅ (602) Confused Math Lady
# ✅ (603) For dummies book
# ✅ (604) Everywhere I go I see his face
# ✅ (605) Drakeposting
# ✅ (606) Blank Trophy
# ✅ (607) Yes Dear
# ✅ (608) And everybody loses their minds
# ✅ (609) Robotnik Pressing Red Button
# ✅ (610) water tank leaking fix
# ✅ (611) Poke with stick
# ✅ (612) Are we the baddies?
# ✅ (613) 2 nickels
# ✅ (614) Angry lady cat
# ✅ (615) My job here is done
# ✅ (616) Arthur Fist
# ✅ (617) Relief
# ✅ (618) fat guy drinking water
# 🔄 Scraping page 17...
# ✅ (619) Corporate needs you to find the differences
# ✅ (620) Here Lies Spongebob Tombstone
# ✅ (621) dr evil pinky
# ✅ (622) Red Button Hand
# ✅ (623) Going to need a bigger boat
# ✅ (624) throw out of the window
# ✅ (625) big yellow ball and...
# ✅ (626) Swerving Car
# ✅ (627) Peasants
# ✅ (628) Gordon Ramsay kids vs adults
# ✅ (629) Small knight giant knight
# ✅ (630) John Daly and Tiger Woods
# ✅ (631) Peter parker reading a book
# ✅ (632) problems stress pain
# ✅ (633) Buzz And Woody
# ✅ (634) Gunna Fire Writing
# ✅ (635) Screaming bird
# ✅ (636) Confused Gandalf
# ✅ (637) my sister's wedding
# ✅ (638) honey it's time to x
# ✅ (639) The Cooler Daniel
# ✅ (640) Fast Flash
# ✅ (641) Won't somebody think of the children
# ✅ (642) Needs More Cowbell
# ✅ (643) Well Yes, But Actually No
# ✅ (644) Oh no anyway
# ✅ (645) sleeping Squidward
# ✅ (646) panie areczku
# ✅ (647) Undertaker teleports behind AJ Styles
# ✅ (648) Pepe holding sign
# ✅ (649) Here we go again
# ✅ (650) Captain Picard Facepalm
# ✅ (651) Inspirational Quote
# ✅ (652) Jack Torrance axe shining
# ✅ (653) Never give up
# ✅ (654) Vince McMahon
# 🔄 Scraping page 18...
# ✅ (655) Breaking News template
# ✅ (656) he man skeleton advices
# ✅ (657) train crashes bus
# ✅ (658) What's on your mind?
# ✅ (659) Skeletor until we meet again
# ✅ (660) what is my purpose
# ✅ (661) perfection
# ✅ (662) Are ya winning son?
# ✅ (663) But It Might Work For Us
# ✅ (664) venn diagram
# ✅ (665) sad thumbs up cat
# ✅ (666) Pippin Second Breakfast
# ✅ (667) Captain Kirk Khan
# ✅ (668) Knight with arrow in helmet
# ✅ (669) No Fear One Fear
# ✅ (670) Nah I'd Win
# ✅ (671) Those who know
# ✅ (672) Spongebob time card background
# ✅ (673) Bugs Bunny no
# ✅ (674) Disappointed Muhammad Sarim Akhtar
# ✅ (675) I think I forgot something
# ✅ (676) I'm in Danger + blank place above
# ✅ (677) Walter White Screaming At Hank
# ✅ (678) Sure grandma
# ✅ (679) Kurt Angle Stare
# ✅ (680) Office Space Bill Lumbergh
# ✅ (681) Gigachad vs virgin
# ✅ (682) Orangutan chasing girl on a tricycle
# ✅ (683) WHICH SIDE ARE YOU ON?
# ✅ (684) You Guys always act like you're better than me
# ✅ (685) Kong Godzilla Doge
# ✅ (686) wanted poster
# ✅ (687) 1984
# ✅ (688) screaming seagull
# ✅ (689) Black Scientist (Finally Xium)
# ✅ (690) Black man crying
# ✅ (691) I am the one who knocks
# 🔄 Scraping page 19...
# ✅ (692) neo dodging a bullet matrix
# ✅ (693) What if you-But god said
# ✅ (694) spongebob fire
# ✅ (695) More likely than you think
# ✅ (696) I've only had Arlo for a day and a half
# ✅ (697) npc-crowd
# ✅ (698) girl running
# ✅ (699) Simpsons bart no
# ✅ (700) You can excuse racism (blank)
# ✅ (701) Back In My Day
# ✅ (702) Say That Again I Dare You
# ✅ (703) That's how you do it
# ✅ (704) Blank
# ✅ (705) Whatcha Got There?
# ✅ (706) Bender
# ✅ (707) I fear no man. But that thing..it scares me
# ✅ (708) Say what again
# ✅ (709) Fancy pooh
# ✅ (710) Blue Grinch
# ✅ (711) Vicious cycle
# ✅ (712) Church gun
# ✅ (713) Thanos Infinity Stones
# ✅ (714) After all.. why not?
# ✅ (715) Dabbing Dude
# ✅ (716) News Headline
# ✅ (717) Confession Bear
# ✅ (718) Yu-Gi-Oh Dramatic Crossroads
# ✅ (719) madness - this is sparta
# ✅ (720) gotta be one of my favorite genders
# ✅ (721) Donald Trump Mugshot
# ✅ (722) Lebron James Reportedly forgot to
# ✅ (723) elmo nuclear explosion
# ✅ (724) Yoda Begun The Clone War Has
# ✅ (725) Spongebob diapers meme
# ✅ (726) Milk Girls
# 🔄 Scraping page 20...
# ✅ (727) Finding Nemo Seagulls
# ✅ (728) Rainbow Six - Fuze The Hostage
# ✅ (729) Amateurs
# ✅ (730) Travis Kelce screaming
# ✅ (731) Nicki Minaj “So there’s this...”
# ✅ (732) Church Sniper
# ✅ (733) iceberg levels tiers
# ✅ (734) Samuel L Jackson say one more time
# ✅ (735) albert einstein quotes
# ✅ (736) Bart Simpson - chalkboard
# ✅ (737) Guy smoking while two people fight
# ✅ (738) Squidward
# ✅ (739) Clippy
# ✅ (740) megamind no b
# ✅ (741) This is sparta!
# ✅ (742) oh thats a toilet spongebob fish
# ✅ (743) Uncanny Pingu
# ✅ (744) who is that pokemon
# ✅ (745) Scooby Doo Unmasking
# ✅ (746) Natalie Portman
# ✅ (747) But it was me Dio
# ✅ (748) Jojo's Walk
# ✅ (749) Inception
# ✅ (750) Hector!!!
# ✅ (751) khan
# ✅ (752) Butterfly man
# ✅ (753) Guy tapping head
# ✅ (754) I said we sad today
# ✅ (755) Feels Good Man
# ✅ (756) Babe! It's 4PM, time for your
# ✅ (757) Cute cat hehe and not hehe
# ✅ (758) You made this?...I made this
# ✅ (759) Get in Loser, We're Going Shopping
# 🔄 Scraping page 21...
# ✅ (760) Seinfeld Newman
# ✅ (761) GTA 5 Franklin and his dog Chop
# ✅ (762) old lady at computer
# ✅ (763) Don Draper Whiteboard
# ✅ (764) Leonardo Dicaprio pointing at tv
# ✅ (765) 4 Spiderman pointing at each other
# ✅ (766) Ok ima fight
# ✅ (767) Coffin Dance
# ✅ (768) Smudge the cat
# ✅ (769) worship the lord
# ✅ (770) Kylo Ren MORE
# ✅ (771) Hans Landa hiding enemies of the state
# ✅ (772) Vanya and Five
# ✅ (773) help me obi wan
# ✅ (774) Bugs bunny I wish all empty template
# ✅ (775) Guy talking to girl in club
# ✅ (776) Tony Soprano in this house
# ✅ (777) Scumbag Steve
# ✅ (778) Blank Transparent Square
# ✅ (779) angry flower
# ✅ (780) What did it cost?
# ✅ (781) let's see paul allen's card
# ✅ (782) Tom chasing Harry and Ron Weasly
# ✅ (783) Squidward competition
# ✅ (784) Black Panther - Get this man a shield
# ✅ (785) Real Shit
# ✅ (786) Spongebob Searching
# ✅ (787) salt bae
# ✅ (788) Smart Guy
# ✅ (789) Thank you for saving my life
# ✅ (790) dad belt template
# ✅ (791) Oh No Black Cat
# ✅ (792) "We did it, Patrick! We saved the City!"
# ✅ (793) Change My Mind (tilt-corrected)
# ✅ (794) Trolley Problem
# ✅ (795) blank black
# ✅ (796) Drake Josh Megan
# 🔄 Scraping page 22...
# ✅ (797) patrick scared
# ✅ (798) Urinal Guy
# ✅ (799) Objects in mirror are closer than they appear
# ✅ (800) sleepy donald duck in bed
# ✅ (801) I love the smell of napalm in the morning
# ✅ (802) Happy sad
# ✅ (803) Metronome
# ✅ (804) Disloyal Boyfriend
# ✅ (805) You Were The Chosen One (Star Wars)
# ✅ (806) Jay Inbetweeners Completed It
# ✅ (807) Pepe Silvia
# ✅ (808) Angry face
# ✅ (809) 4 headed dragon
# ✅ (810) Zombieland money tears
# ✅ (811) Suspicious Dog
# ✅ (812) Michael Jackson popcorn gif
# ✅ (813) Mental Gymnastics
# ✅ (814) Are you winning son blank template
# ✅ (815) hitler speech
# ✅ (816) You Should Feel Bad Zoidberg
# ✅ (817) Fancy Winnie The Pooh Meme
# ✅ (818) Tuxedo Winnie the Pooh grossed reverse
# ✅ (819) small brain yelling at big brain
# ✅ (820) Robert Downey Jr's Comments
# ✅ (821) Dog on fire
# ✅ (822) They don't even have dental
# ✅ (823) We are the millers
# ✅ (824) Guy getting beat up
# ✅ (825) Tom & Jerry Searching
# ✅ (826) Jesse WTF are you talking about?
# ✅ (827) Walter White Breaks Down
# ✅ (828) Keyboard Typing
# 🔄 Scraping page 23...
# ✅ (829) It cant hurt you
# ✅ (830) We are not the same
# ✅ (831) I Robot Will Smith
# ✅ (832) James Franco First Time
# ✅ (833) Mr T Pity The Fool
# ✅ (834) Anime girl buying
# ✅ (835) Apu takes bullet
# ✅ (836) Surprise anime guy
# ✅ (837) Plane flying from explosions
# ✅ (838) Trumpet Boy
# ✅ (839) stonks
# ✅ (840) Impressive, very nice
# ✅ (841) Its Not Going To Happen
# ✅ (842) no disparen/ Dont shoot
# ✅ (843) Pablo escobar waiting alone
# ✅ (844) Happy then sad
# ✅ (845) Ermahgerd Berks
# ✅ (846) In terms of money, we have no money
# ✅ (847) Think Mark Think
# ✅ (848) Ron Swanson trash computer
# ✅ (849) South Park JIzz
# ✅ (850) Monster Inc. Walking
# ✅ (851) 3D Nerd Emoji
# ✅ (852) crying girl dancing guy
# ✅ (853) People Raising Hands
# ✅ (854) At home
# ✅ (855) Windows Error Message
# ✅ (856) You're laughing.
# ✅ (857) Tintin and Haddock
# ✅ (858) Grandpa Simpson Hat
# ✅ (859) Blank Tombstone
# ✅ (860) Meme Stealing License
# ✅ (861) Tornado Guy
# ✅ (862) youtube video template
# ✅ (863) Men Discussing Men Fighting
# ✅ (864) Why you no
# ✅ (865) Smokey The Bear
# ✅ (866) Kermit sipping tea
# 🔄 Scraping page 24...
# ✅ (867) Sitting Wolf
# ✅ (868) Gollum
# ✅ (869) Arrested Development how much would a banana cost
# ✅ (870) Dean Norris's reaction
# ✅ (871) Vegeta over 9000
# ✅ (872) He was a boy, she was a girl
# ✅ (873) Tell me the truth, I'm ready to hear it
# ✅ (874) Smash Bros.
# ✅ (875) Interstellar Smoking
# ✅ (876) Is this a bird?
# ✅ (877) Naruto Handshake Meme Template
# ✅ (878) I hate the Antichrist
# ✅ (879) Here's Johnny
# ✅ (880) How could they have done this
# ✅ (881) Steamboat Willie
# ✅ (882) Spongegar
# ✅ (883) death battle
# ✅ (884) Mr Krabs Blur Meme
# ✅ (885) McDonald’s Happy Meal Dance Gif
# ✅ (886) Burning Money
# ✅ (887) Overly Attached Girlfriend
# ✅ (888) screaming gopher
# ✅ (889) Giant Thumb Guy
# ✅ (890) BEST I CAN DO IS
# ✅ (891) ANIME BUTTERFLY MEME
# ✅ (892) DBZ FUSION
# ✅ (893) genuinely tweaking skeleton
# ✅ (894) Leonardo DiCaprio throwing Money
# ✅ (895) Shrek Cat
# ✅ (896) Be Like Bill
# ✅ (897) Star Wars No
# ✅ (898) ANDY DROPPING WOODY
# ✅ (899) puppet Monkey looking away
# ✅ (900) Trade offer meme Animated gif
# ✅ (901) Puppet hierarchy
# ✅ (902) You Merely Adopted X I Was Born In It,Molded By It
# ✅ (903) Worst mistake of my life
# ✅ (904) Bill Murray Groundhog Day
# 🔄 Scraping page 25...
# ✅ (905) Run!
# ✅ (906) They dont know "....."
# ✅ (907) Forever alone
# ✅ (908) One please
# ✅ (909) Spongebob box
# ✅ (910) Dr Evil Quotes
# ✅ (911) Harry, You Don't Need to Sell It To Me
# ✅ (912) rick and morty-extra steps
# ✅ (913) Kicking out Simpsons
# ✅ (914) Jealous Girlfriend
# ✅ (915) jesus watcha doin
# ✅ (916) 2 gay black mens kissing
# ✅ (917) Slowpoke
# ✅ (918) Scout opening the fridge
# ✅ (919) spongebob panic inside
# ✅ (920) the office bankruptcy
# ✅ (921) breaking bad smile frown
# ✅ (922) Professor Farnsworth Good News Everyone
# ✅ (923) Is Fortnite Actually Overrated?
# ✅ (924) Nah yeah
# ✅ (925) Impractical Jokers
# ✅ (926) The Simpsons Ralph Wiggum Picking His Nose
# ✅ (927) Monkey looking away
# ✅ (928) First rule of the Fight Club
# ✅ (929) Nick Young
# ✅ (930) Hulk
# ✅ (931) Licking lips
# ✅ (932) minions
# ✅ (933) Eddie Murphy thinking
# ✅ (934) Is This A blank
# ✅ (935) Morgan Freeman
# ✅ (936) What if you wanted to go to Heaven
# ✅ (937) Dwight Schrute
# ✅ (938) crying michael jordan
# ✅ (939) braveheart freedom
# ✅ (940) peter griffin beats up kyle
# ✅ (941) Soldiers hold up society
# 🔄 Scraping page 26...
# ✅ (942) Chad Richard
# ✅ (943) The Loudest Sounds on Earth
# ✅ (944) Reaction Guys
# ✅ (945) Executive Order Trump
# ✅ (946) Epic Handshake Three Way
# ✅ (947) Darth Vader Where is Padme?
# ✅ (948) slap that button
# ✅ (949) Girl Putting Tuba on Girl's Head
# ✅ (950) hypnosis
# ✅ (951) Dr Evil One Million
# ✅ (952) 10 Guy
# ✅ (953) Angry Baby
# ✅ (954) Kirby eating
# ✅ (955) blank kermit waiting
# ✅ (956) Drake Hotline approves
# ✅ (957) HOMER BUSH
# ✅ (958) drake yes no reverse
# ✅ (959) Doomguy
# ✅ (960) Deep Thoughts
# ✅ (961) Straight Outta X blank template
# ✅ (962) Finally, inner peace.
# ✅ (963) Water Dam Meme
# ✅ (964) Symphony Meme
# ✅ (965) couple in bed
# ✅ (966) Sonic Says
# ✅ (967) skinner pathetic
# ✅ (968) Young Thug and Lil Durk troubleshooting
# ✅ (969) Im gonna say it
# ✅ (970) dj khaled suffering from success meme
# ✅ (971) am I a joke to you
# ✅ (972) Sarcastic spongebob
# ✅ (973) Guy posing in front of grave
# ✅ (974) Surprised Pikachu (High Quality)
# ✅ (975) Jump on Rake
# ✅ (976) I just think they're neat
# ✅ (977) Pinky and the brain
# ✅ (978) laughing kid
# 🔄 Scraping page 27...
# ✅ (979) Czas na csa
# ✅ (980) Manly Handshake
# ✅ (981) See You Again
# ✅ (982) We Have A Hulk
# ✅ (983) Fairly odd parents
# ✅ (984) Paulo Coelho
# ✅ (985) breaking bad
# ✅ (986) Hand clasping
# ✅ (987) Anakin Padme Meme
# ✅ (988) Phoebe teaching Joey in Friends
# ✅ (989) Bee Movie Lawyer Tantrum
# ✅ (990) Grim Reaper Claw Machine
# ✅ (991) Go and get the guitar
# ✅ (992) Angry penguin
# ✅ (993) Black guy disappearing
# ✅ (994) Car Drift Meme
# ✅ (995) Bird Cracker
# ✅ (996) Gabe - shut up about the sun
# ✅ (997) Szia uram (uncropped)
# ✅ (998) Unsheathing Sword
# ✅ (999) La Roca: Ayer Vino
# ✅ (1000) GALAXY BRAIN
#
# 🎉 Finished! Downloaded 1000 meme templates.

# %% [markdown]
# ---

# %%
import os
import pandas as pd
import json
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables
load_dotenv()

# Initialize OpenAI client (v1.x)
client = OpenAI(api_key=os.getenv("OPENAI_KEY"))

# === CONFIGURATION ===
TEMPLATE_DIR = r"C:\Users\hp\Desktop\fyp\mvp\M2-meme-gen\meme-templates-updated-2"
BATCH_SIZE = 20
MODEL = "gpt-4"
OUTPUT_FILE = "meme_features_new.csv"

# === ENUMS for Constrained Fields ===
OPTION_SETS = {
    "Primary Audience": ["Gen Z", "Millennials", "Young Adults", "Parents", "Professionals", "Gamers", "Students", "General Public"],
    "Humor Style": ["Sarcastic", "Wholesome", "Witty", "Relatable", "Cringe", "Absurd"]
}

# === Prompt Builder ===
def build_prompt(meme_names: list) -> str:
    formatted_memes = "\n".join(f"- {name}" for name in meme_names)
    return f"""
You are an AI trained to classify meme templates for marketing analysis.

For each meme template, return a JSON object with the following fields:
- Meme Name (string)
- Primary Audience (one from: {OPTION_SETS['Primary Audience']})
- Humor Style (one from: {OPTION_SETS['Humor Style']})
- Keywords (5–10 general descriptive terms, not including the meme name)

❌ Do NOT include the meme title in the keywords.
✅ Keywords should reflect the meme's emotional or situational context.

Meme Templates:
{formatted_memes}

Return only a single JSON object in this format: {{ "memes": [ ... ] }}
"""

# === Call OpenAI API ===
def call_openai_batch(batch_names):
    prompt = build_prompt(batch_names)
    response = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": prompt}],
        temperature=0.5,
    )
    content = response.choices[0].message.content.strip()
    return json.loads(content)["memes"]

# === Main Runner ===
def run_minimal_meme_extraction():
    # Extract meme names from filenames
    meme_names = [os.path.splitext(f)[0].replace("_", " ") for f in os.listdir(TEMPLATE_DIR)
                  if f.lower().endswith((".jpg", ".png"))]
    all_results = []

    print(f"🗂 Found {len(meme_names)} meme templates.")

    for i in range(0, len(meme_names), BATCH_SIZE):
        batch = meme_names[i:i + BATCH_SIZE]
        print(f"🔍 Processing batch {i//BATCH_SIZE + 1}...")
        try:
            results = call_openai_batch(batch)
            all_results.extend(results)
        except Exception as e:
            print(f"❌ Error in batch {batch}: {e}")
            continue

    # Save results
    df = pd.DataFrame(all_results)
    df.to_csv(OUTPUT_FILE, index=False)
    print(f"\n✅ Done! Saved to {OUTPUT_FILE}")

# Run
if __name__ == "__main__":
    run_minimal_meme_extraction()
# Out:
# 🗂 Found 834 meme templates.
# 🔍 Processing batch 1...
# 🔍 Processing batch 2...
# 🔍 Processing batch 3...
# 🔍 Processing batch 4...
# 🔍 Processing batch 5...
# 🔍 Processing batch 6...
# 🔍 Processing batch 7...
# 🔍 Processing batch 8...
# 🔍 Processing batch 9...
# 🔍 Processing batch 10...
# 🔍 Processing batch 11...
# 🔍 Processing batch 12...
# 🔍 Processing batch 13...
# 🔍 Processing batch 14...
# 🔍 Processing batch 15...
# 🔍 Processing batch 16...
# 🔍 Processing batch 17...
# 🔍 Processing batch 18...
# 🔍 Processing batch 19...
# 🔍 Processing batch 20...
# 🔍 Processing batch 21...
# 🔍 Processing batch 22...
# 🔍 Processing batch 23...
# 🔍 Processing batch 24...
# 🔍 Processing batch 25...
# 🔍 Processing batch 26...
# 🔍 Processing batch 27...
# 🔍 Processing batch 28...
# 🔍 Processing batch 29...
# 🔍 Processing batch 30...
# 🔍 Processing batch 31...
# 🔍 Processing batch 32...
# 🔍 Processing batch 33...
# 🔍 Processing batch 34...
# 🔍 Processing batch 35...
# 🔍 Processing batch 36...
# 🔍 Processing batch 37...
# 🔍 Processing batch 38...
# 🔍 Processing batch 39...
# 🔍 Processing batch 40...
# 🔍 Processing batch 41...
# 🔍 Processing batch 42...
#
# ✅ Done! Saved to meme_features_new.csv

# %%
import os
import re

TEMPLATE_FOLDER = r"C:\Users\hp\Desktop\fyp\mvp\M2-meme-gen\meme-templates-updated-2"

def normalize_filename(name):
    # Remove leading/trailing whitespace and extension
    base, ext = os.path.splitext(name)
    # Replace spaces and repeated underscores with a single underscore
    normalized = re.sub(r'[\s]+', '_', base)
    normalized = re.sub(r'[_]+', '_', normalized)
    normalized = normalized.lower().strip('_')
    return normalized + ext.lower()

def normalize_all_filenames(folder):
    renamed = []
    for filename in os.listdir(folder):
        old_path = os.path.join(folder, filename)
        if not os.path.isfile(old_path):
            continue

        new_filename = normalize_filename(filename)
        new_path = os.path.join(folder, new_filename)

        # Only rename if different
        if old_path != new_path:
            os.rename(old_path, new_path)
            renamed.append((filename, new_filename))

    return renamed

# === Run the normalization ===
renamed_files = normalize_all_filenames(TEMPLATE_FOLDER)
print("✅ Normalized filenames:")
for old, new in renamed_files:
    print(f"{old} → {new}")
# Out:
# ✅ Normalized filenames:
# 0_days_without__Lenny__Simpsons_.jpg → 0_days_without_lenny_simpsons.jpg
# 1984_Calendar.jpg → 1984_calendar.jpg
# 3D_Nerd_Emoji.jpg → 3d_nerd_emoji.jpg
# 3_Spiderman_Pointing.jpg → 3_spiderman_pointing.jpg
# 4_Spiderman_pointing_at_each_other.jpg → 4_spiderman_pointing_at_each_other.jpg
# Aaaaand_Its_Gone.jpg → aaaaand_its_gone.jpg
# Absolute_Cinema.jpg → absolute_cinema.jpg
# Adam_Silver_Get_Ready_To_Learn_Buddy.jpg → adam_silver_get_ready_to_learn_buddy.jpg
# Afraid_To_Ask_Andy.jpg → afraid_to_ask_andy.jpg
# After_all___why_not_.jpg → after_all_why_not.jpg
# AJ_Styles___Undertaker.jpg → aj_styles_undertaker.jpg
# All_My_Homies_Hate.jpg → all_my_homies_hate.jpg
# Always_Has_Been.jpg → always_has_been.jpg
# Always_you_three.jpg → always_you_three.jpg
# Amateurs.jpg → amateurs.jpg
# am_I_a_joke_to_you.jpg → am_i_a_joke_to_you.jpg
# Am_I_The_Only_One_Around_Here.jpg → am_i_the_only_one_around_here.jpg
# Ancient_Aliens.jpg → ancient_aliens.jpg
# ANDY_DROPPING_WOODY.jpg → andy_dropping_woody.jpg
# Andy_Dwyer_Excited.jpg → andy_dwyer_excited.jpg
# And_everybody_loses_their_minds.jpg → and_everybody_loses_their_minds.jpg
# and_I_took_that_personally.jpg → and_i_took_that_personally.jpg
# And_Just_Like_That.jpg → and_just_like_that.jpg
# Angela_scared_Dwight.jpg → angela_scared_dwight.jpg
# Angry_Baby.jpg → angry_baby.jpg
# Angry_lady_cat.jpg → angry_lady_cat.jpg
# Angry_Man_pointing_at_hand.jpg → angry_man_pointing_at_hand.jpg
# Angry_penguin.jpg → angry_penguin.jpg
# ANIME_BUTTERFLY_MEME.jpg → anime_butterfly_meme.jpg
# Anime_girl_buying.jpg → anime_girl_buying.jpg
# Anime_Girl_Hiding_from_Terminator.jpg → anime_girl_hiding_from_terminator.jpg
# Anthony_Adams_Rubbing_Hands.jpg → anthony_adams_rubbing_hands.jpg
# Apu_takes_bullet.jpg → apu_takes_bullet.jpg
# Aragorn_Black_Gate_for_Frodo.jpg → aragorn_black_gate_for_frodo.jpg
# Are_they_in_the_room_with_us_right_now_.jpg → are_they_in_the_room_with_us_right_now.jpg
# Are_we_the_baddies_.jpg → are_we_the_baddies.jpg
# Are_ya_winning_son_.jpg → are_ya_winning_son.jpg
# Army_clown.jpg → army_clown.jpg
# Arm_wrestling_meme_template.jpg → arm_wrestling_meme_template.jpg
# Arrested_Development_how_much_would_a_banana_cost.jpg → arrested_development_how_much_would_a_banana_cost.jpg
# Arthur_Fist.jpg → arthur_fist.jpg
# Assassination_chain.jpg → assassination_chain.jpg
# Atlas_holding_Earth.jpg → atlas_holding_earth.jpg
# At_home.jpg → at_home.jpg
# Average_Fan_vs_Average_Enjoyer.jpg → average_fan_vs_average_enjoyer.jpg
# A_center_for_ants_.jpg → a_center_for_ants.jpg
# A_second_plane_has_just_hit.jpg → a_second_plane_has_just_hit.jpg
# A_train_hitting_a_school_bus.jpg → a_train_hitting_a_school_bus.jpg
# Babe__It_s_4PM__time_for_your.jpg → babe_it_s_4pm_time_for_your.jpg
# Back_In_My_Day.jpg → back_in_my_day.jpg
# Badass_Skeleton.jpg → badass_skeleton.jpg
# Bad_Luck_Brian.jpg → bad_luck_brian.jpg
# Bad_Pun_Dog.jpg → bad_pun_dog.jpg
# Bart_Simpson___chalkboard.jpg → bart_simpson_chalkboard.jpg
# Bateman_walking.jpg → bateman_walking.jpg
# Batman_Slapping_Robin.jpg → batman_slapping_robin.jpg
# Bee_Movie_Lawyer_Tantrum.jpg → bee_movie_lawyer_tantrum.jpg
# Bell_Curve.jpg → bell_curve.jpg
# Bender.jpg → bender.jpg
# Ben_affleck_smoking.jpg → ben_affleck_smoking.jpg
# Bernie_I_Am_Once_Again_Asking_For_Your_Support.jpg → bernie_i_am_once_again_asking_for_your_support.jpg
# Bernie_Sanders_Once_Again_Asking.jpg → bernie_sanders_once_again_asking.jpg
# BEST_I_CAN_DO_IS.jpg → best_i_can_do_is.jpg
# Beyoncé____Tiffany_Pollard.jpg → beyoncé_tiffany_pollard.jpg
# Be_Like_Bill.jpg → be_like_bill.jpg
# Big_book_small_book.jpg → big_book_small_book.jpg
# Big_dog_small_dog.jpg → big_dog_small_dog.jpg
# Big_thumb_guy.jpg → big_thumb_guy.jpg
# big_yellow_ball_and___.jpg → big_yellow_ball_and.jpg
# Bike_Fall.jpg → bike_fall.jpg
# Bilbo___Why_shouldn_t_I_keep_it_.jpg → bilbo_why_shouldn_t_i_keep_it.jpg
# Bill_Murray_Groundhog_Day.jpg → bill_murray_groundhog_day.jpg
# Bird_Cracker.jpg → bird_cracker.jpg
# Blackjack_and_Hookers.jpg → blackjack_and_hookers.jpg
# Black_background.jpg → black_background.jpg
# Black_Box_Meme.jpg → black_box_meme.jpg
# Black_Girl_Wat.jpg → black_girl_wat.jpg
# Black_guy_disappearing.jpg → black_guy_disappearing.jpg
# Black_guy_hiding_behind_tree.jpg → black_guy_hiding_behind_tree.jpg
# Black_man_crying.jpg → black_man_crying.jpg
# Black_Panther___Get_this_man_a_shield.jpg → black_panther_get_this_man_a_shield.jpg
# Black_Scientist__Finally_Xium_.jpg → black_scientist_finally_xium.jpg
# Black_White_Arms.jpg → black_white_arms.jpg
# Blank.jpg → blank.jpg
# Blank_Nut_Button.jpg → blank_nut_button.jpg
# Blank_protest_sign.jpg → blank_protest_sign.jpg
# blank_red_MAGA_hat.jpg → blank_red_maga_hat.jpg
# Blank_Tombstone.jpg → blank_tombstone.jpg
# Blank_Transparent_Square.jpg → blank_transparent_square.jpg
# Blank_Trophy.jpg → blank_trophy.jpg
# Blank_T_Shirt.jpg → blank_t_shirt.jpg
# Blank_White_Template.jpg → blank_white_template.jpg
# Blank_Wild_Pokemon_Appears.jpg → blank_wild_pokemon_appears.jpg
# Blue_Grinch.jpg → blue_grinch.jpg
# Boardroom_Meeting_Suggestion.jpg → boardroom_meeting_suggestion.jpg
# Body_is_a_Machine.jpg → body_is_a_machine.jpg
# Borat_2_Tonight_Queen__.jpg → borat_2_tonight_queen.jpg
# Born_Died_Welcome_Back.jpg → born_died_welcome_back.jpg
# Both_Buttons_Pressed.jpg → both_buttons_pressed.jpg
# Brace_Yourselves_X_is_Coming.jpg → brace_yourselves_x_is_coming.jpg
# Breaking_News_template.jpg → breaking_news_template.jpg
# Bro_explaining.jpg → bro_explaining.jpg
# Bro_Please_Bro.jpg → bro_please_bro.jpg
# Bro_visited_his_friend.jpg → bro_visited_his_friend.jpg
# Buddy_Christ.jpg → buddy_christ.jpg
# Buff_Doge_vs__Cheems.jpg → buff_doge_vs_cheems.jpg
# Bugs_bunny_communist.jpg → bugs_bunny_communist.jpg
# Bugs_bunny_I_wish_all_empty_template.jpg → bugs_bunny_i_wish_all_empty_template.jpg
# Bugs_Bunny_no.jpg → bugs_bunny_no.jpg
# Burning_House_Girl.jpg → burning_house_girl.jpg
# Burning_Money.jpg → burning_money.jpg
# Butterfly_man.jpg → butterfly_man.jpg
# But_it_was_me_Dio.jpg → but_it_was_me_dio.jpg
# But_That_s_None_Of_My_Business.jpg → but_that_s_none_of_my_business.jpg
# Buzz_And_Woody.jpg → buzz_and_woody.jpg
# Buzz_lightyear_clones.jpg → buzz_lightyear_clones.jpg
# Call_an_ambulance_but_not_for_me.jpg → call_an_ambulance_but_not_for_me.jpg
# Captain_Kirk_Khan.jpg → captain_kirk_khan.jpg
# Captain_Phillips___I_m_The_Captain_Now.jpg → captain_phillips_i_m_the_captain_now.jpg
# Captain_Picard_Facepalm.jpg → captain_picard_facepalm.jpg
# Cars_Passing_Each_Other.jpg → cars_passing_each_other.jpg
# Car_Drift_Meme.jpg → car_drift_meme.jpg
# Car_drives_off_of_cliff__improved_.jpg → car_drives_off_of_cliff_improved.jpg
# Car_Salesman_Slaps_Roof_Of_Car.jpg → car_salesman_slaps_roof_of_car.jpg
# Cat_looks_inside.jpg → cat_looks_inside.jpg
# Cat_newspaper.jpg → cat_newspaper.jpg
# Chad_Richard.jpg → chad_richard.jpg
# Change_My_Mind.jpg → change_my_mind.jpg
# Change_My_Mind__tilt_corrected_.jpg → change_my_mind_tilt_corrected.jpg
# Chapelle_crack.jpg → chapelle_crack.jpg
# Charlie_Conspiracy__Always_Sunny_in_Philidelphia_.jpg → charlie_conspiracy_always_sunny_in_philidelphia.jpg
# Charlie_Day.jpg → charlie_day.jpg
# Chef_Skinner_Reading_a_Letter.jpg → chef_skinner_reading_a_letter.jpg
# Children_scared_of_rabbit.jpg → children_scared_of_rabbit.jpg
# Chill_guy.jpg → chill_guy.jpg
# Church_gun.jpg → church_gun.jpg
# Church_Sniper.jpg → church_sniper.jpg
# Clippy.jpg → clippy.jpg
# Clown_Applying_Makeup.jpg → clown_applying_makeup.jpg
# Clown_Makeup_slander.jpg → clown_makeup_slander.jpg
# Coffin_Dance.jpg → coffin_dance.jpg
# Community_Fire_Pizza_Meme.jpg → community_fire_pizza_meme.jpg
# Confession_Bear.jpg → confession_bear.jpg
# Confused_Gandalf.jpg → confused_gandalf.jpg
# Confused_John_Travolta_Pulp_Fiction.jpg → confused_john_travolta_pulp_fiction.jpg
# Confused_Math_Lady.jpg → confused_math_lady.jpg
# Confused_Monkey.jpg → confused_monkey.jpg
# Corporate_needs_you_to_find_the_differences.jpg → corporate_needs_you_to_find_the_differences.jpg
# Crab_Rave.jpg → crab_rave.jpg
# Creepy_Condescending_Wonka.jpg → creepy_condescending_wonka.jpg
# Crying_cat.jpg → crying_cat.jpg
# Crying_Hulk.jpg → crying_hulk.jpg
# Cuphead_Flower.jpg → cuphead_flower.jpg
# Cute_Cat.jpg → cute_cat.jpg
# Cute_cat_hehe_and_not_hehe.jpg → cute_cat_hehe_and_not_hehe.jpg
# Dabbing_Dude.jpg → dabbing_dude.jpg
# Dancing_monkeys.jpg → dancing_monkeys.jpg
# Dancin_bois.jpg → dancin_bois.jpg
# Darth_Vader.jpg → darth_vader.jpg
# Darth_Vader_Where_is_Padme_.jpg → darth_vader_where_is_padme.jpg
# DBZ_FUSION.jpg → dbz_fusion.jpg
# Dead_Baby_Voldemort___What_Happened_To_Him.jpg → dead_baby_voldemort_what_happened_to_him.jpg
# Dean_Norris_s_reaction.jpg → dean_norris_s_reaction.jpg
# Deep_Thoughts.jpg → deep_thoughts.jpg
# Did_you_mean_.jpg → did_you_mean.jpg
# Dinkleberg.jpg → dinkleberg.jpg
# Disappearing_kid_gif.jpg → disappearing_kid_gif.jpg
# Disappointed_Black_Guy.jpg → disappointed_black_guy.jpg
# Disappointed_Man.jpg → disappointed_man.jpg
# Disappointed_Muhammad_Sarim_Akhtar.jpg → disappointed_muhammad_sarim_akhtar.jpg
# Disaster_Girl.jpg → disaster_girl.jpg
# Disloyal_Boyfriend.jpg → disloyal_boyfriend.jpg
# Distracted_Boyfriend.jpg → distracted_boyfriend.jpg
# Doctor_Fate.jpg → doctor_fate.jpg
# Doge.jpg → doge.jpg
# Dog_on_fire.jpg → dog_on_fire.jpg
# Domino_Effect.jpg → domino_effect.jpg
# Donald_Trump.jpg → donald_trump.jpg
# Donald_trump_approves.jpg → donald_trump_approves.jpg
# Donald_Trump_Mugshot.jpg → donald_trump_mugshot.jpg
# Don_Draper_Whiteboard.jpg → don_draper_whiteboard.jpg
# Don_t_make_me_tap_the_sign.jpg → don_t_make_me_tap_the_sign.jpg
# Don_t_You_Squidward.jpg → don_t_you_squidward.jpg
# Doof_If_I_had_a_Nickel.jpg → doof_if_i_had_a_nickel.jpg
# Doomguy.jpg → doomguy.jpg
# Do_all_the_things.jpg → do_all_the_things.jpg
# Drakeposting.jpg → drakeposting.jpg
# Drake_Josh_Megan.jpg → drake_josh_megan.jpg
# drowning_kid___skeleton.jpg → drowning_kid_skeleton.jpg
# Dr_Evil_Laser.jpg → dr_evil_laser.jpg
# Dwight_Schrute.jpg → dwight_schrute.jpg
# DW_Sign_Won_t_Stop_Me_Because_I_Can_t_Read.jpg → dw_sign_won_t_stop_me_because_i_can_t_read.jpg
# Eddie_Murphy_thinking.jpg → eddie_murphy_thinking.jpg
# Empty_Stonks.jpg → empty_stonks.jpg
# Epic_Handshake.jpg → epic_handshake.jpg
# Ermahgerd_Berks.jpg → ermahgerd_berks.jpg
# Everywhere_I_go_I_see_his_face.jpg → everywhere_i_go_i_see_his_face.jpg
# Evil_Kermit.jpg → evil_kermit.jpg
# Evil_Toddler.jpg → evil_toddler.jpg
# Ew__i_stepped_in_shit.jpg → ew_i_stepped_in_shit.jpg
# Executive_Order_Trump.jpg → executive_order_trump.jpg
# Face_You_Make_Robert_Downey_Jr.jpg → face_you_make_robert_downey_jr.jpg
# Fairly_odd_parents.jpg → fairly_odd_parents.jpg
# Fake_search.jpg → fake_search.jpg
# Fancy_Winnie_The_Pooh_Meme.jpg → fancy_winnie_the_pooh_meme.jpg
# Fantasy_Painting.jpg → fantasy_painting.jpg
# Farquaad_Pointing.jpg → farquaad_pointing.jpg
# Fast_Flash.jpg → fast_flash.jpg
# Feels_Good_Man.jpg → feels_good_man.jpg
# Feel_like_pure_shit.jpg → feel_like_pure_shit.jpg
# Fernanfloo_Dresses_Up.jpg → fernanfloo_dresses_up.jpg
# FINALLY.jpg → finally.jpg
# Finally__inner_peace_.jpg → finally_inner_peace.jpg
# Finding_Nemo_Seagulls.jpg → finding_nemo_seagulls.jpg
# First_rule_of_the_Fight_Club.jpg → first_rule_of_the_fight_club.jpg
# First_World_Problems.jpg → first_world_problems.jpg
# Flex_Tape.jpg → flex_tape.jpg
# For_Dummies.jpg → for_dummies.jpg
# For_dummies_book.jpg → for_dummies_book.jpg
# Funeral.jpg → funeral.jpg
# Futurama_Fry.jpg → futurama_fry.jpg
# Futurama_Zero_Days_Since_Last_Blank.jpg → futurama_zero_days_since_last_blank.jpg
# Futuristic_Utopia.jpg → futuristic_utopia.jpg
# F_dinosaur.jpg → f_dinosaur.jpg
# Gabe___shut_up_about_the_sun.jpg → gabe_shut_up_about_the_sun.jpg
# Gentleman_frog.jpg → gentleman_frog.jpg
# Geordi_Drake.jpg → geordi_drake.jpg
# George_Bush_9_11.jpg → george_bush_9_11.jpg
# Get_in_Loser__We_re_Going_Shopping.jpg → get_in_loser_we_re_going_shopping.jpg
# Giant_vs_man.jpg → giant_vs_man.jpg
# Gigachad_vs_virgin.jpg → gigachad_vs_virgin.jpg
# Girl_Putting_Tuba_on_Girl_s_Head.jpg → girl_putting_tuba_on_girl_s_head.jpg
# Going_to_need_a_bigger_boat.jpg → going_to_need_a_bigger_boat.jpg
# Gollum.jpg → gollum.jpg
# Good_Fellas_Hilarious.jpg → good_fellas_hilarious.jpg
# Goose_Chase.jpg → goose_chase.jpg
# Go_and_get_the_guitar.jpg → go_and_get_the_guitar.jpg
# Go_Fund_Me.jpg → go_fund_me.jpg
# Grandma_Finds_The_Internet.jpg → grandma_finds_the_internet.jpg
# Grandpa_Simpson_Hat.jpg → grandpa_simpson_hat.jpg
# Grant_Gustin_over_grave.jpg → grant_gustin_over_grave.jpg
# Gravestone.jpg → gravestone.jpg
# Greedy_Pipe_Man.jpg → greedy_pipe_man.jpg
# Grim_Reaper_Claw_Machine.jpg → grim_reaper_claw_machine.jpg
# Grim_Reaper_Knocking_Door.jpg → grim_reaper_knocking_door.jpg
# Grumpy_Cat.jpg → grumpy_cat.jpg
# Gru_Gun.jpg → gru_gun.jpg
# GTA_5_Franklin_and_his_dog_Chop.jpg → gta_5_franklin_and_his_dog_chop.jpg
# Guess_I_ll_die.jpg → guess_i_ll_die.jpg
# Gunna_Fire_Writing.jpg → gunna_fire_writing.jpg
# Gus_Fring_we_are_not_the_same.jpg → gus_fring_we_are_not_the_same.jpg
# Guy_in_corner_of_party.jpg → guy_in_corner_of_party.jpg
# Guy_in_the_suit.jpg → guy_in_the_suit.jpg
# Guy_posing_in_front_of_grave.jpg → guy_posing_in_front_of_grave.jpg
# Guy_recording_a_fight.jpg → guy_recording_a_fight.jpg
# Guy_smoking_while_two_people_fight.jpg → guy_smoking_while_two_people_fight.jpg
# Guy_talking_to_girl_in_club.jpg → guy_talking_to_girl_in_club.jpg
# Guy_tapping_head.jpg → guy_tapping_head.jpg
# Hand_clasping.jpg → hand_clasping.jpg
# Hans_Landa_hiding_enemies_of_the_state.jpg → hans_landa_hiding_enemies_of_the_state.jpg
# Happy_dolphin_rainbow.jpg → happy_dolphin_rainbow.jpg
# Happy_sad.jpg → happy_sad.jpg
# Happy_Star_Congratulations.jpg → happy_star_congratulations.jpg
# Happy___Shock.jpg → happy_shock.jpg
# Hard_To_Swallow_Pills.jpg → hard_to_swallow_pills.jpg
# Hector___.jpg → hector.jpg
# Here_it_comes.jpg → here_it_comes.jpg
# Here_Lies_Spongebob_Tombstone.jpg → here_lies_spongebob_tombstone.jpg
# Here_s_Johnny.jpg → here_s_johnny.jpg
# Here_we_go_again.jpg → here_we_go_again.jpg
# He_s_probably_thinking_about_girls.jpg → he_s_probably_thinking_about_girls.jpg
# He_was_a_boy__she_was_a_girl.jpg → he_was_a_boy_she_was_a_girl.jpg
# Hide_the_Pain_Harold.jpg → hide_the_pain_harold.jpg
# Hold_fart.jpg → hold_fart.jpg
# Homer_disappears_into_bush.jpg → homer_disappears_into_bush.jpg
# Homer_Simpson_sleeping_peacefully.jpg → homer_simpson_sleeping_peacefully.jpg
# Horse_Drawing.jpg → horse_drawing.jpg
# How_could_they_have_done_this.jpg → how_could_they_have_done_this.jpg
# Hulk.jpg → hulk.jpg
# Hulk_Taco.jpg → hulk_taco.jpg
# Hypnotize.jpg → hypnotize.jpg
# Illusion_of_free_choice.jpg → illusion_of_free_choice.jpg
# Imagination_Spongebob.jpg → imagination_spongebob.jpg
# Impractical_Jokers.jpg → impractical_jokers.jpg
# Impressive__very_nice.jpg → impressive_very_nice.jpg
# Im_gonna_say_it.jpg → im_gonna_say_it.jpg
# Insane_Peter.jpg → insane_peter.jpg
# Interstellar_Smoking.jpg → interstellar_smoking.jpg
# In_terms_of_money__we_have_no_money.jpg → in_terms_of_money_we_have_no_money.jpg
# Is_Fortnite_Actually_Overrated_.jpg → is_fortnite_actually_overrated.jpg
# Is_this_a_bird_.jpg → is_this_a_bird.jpg
# Its_Not_Going_To_Happen.jpg → its_not_going_to_happen.jpg
# It_ain_t_much__but_it_s_honest_work.jpg → it_ain_t_much_but_it_s_honest_work.jpg
# It_cant_hurt_you.jpg → it_cant_hurt_you.jpg
# It_s_been_84_years.jpg → it_s_been_84_years.jpg
# I_am_going_to_create_an_environment_that_is_so_toxic__blank_.jpg → i_am_going_to_create_an_environment_that_is_so_toxic_blank.jpg
# I_am_once_again_asking.jpg → i_am_once_again_asking.jpg
# I_am_the_one_who_knocks.jpg → i_am_the_one_who_knocks.jpg
# I_believe_in_supremacy.jpg → i_believe_in_supremacy.jpg
# I_Bet_He_s_Thinking_About_Other_Women.jpg → i_bet_he_s_thinking_about_other_women.jpg
# I_can_has_cheezburger_cat.jpg → i_can_has_cheezburger_cat.jpg
# I_don_t_care_if_you_win__I_just_need_X_to_lose.jpg → i_don_t_care_if_you_win_i_just_need_x_to_lose.jpg
# I_don_t_think_about_you_at_all_Mad_Men.jpg → i_don_t_think_about_you_at_all_mad_men.jpg
# I_don_t_want_to_play_with_you_anymore.jpg → i_don_t_want_to_play_with_you_anymore.jpg
# I_hate_the_Antichrist.jpg → i_hate_the_antichrist.jpg
# I_just_think_they_re_neat.jpg → i_just_think_they_re_neat.jpg
# I_ll_Just_Wait_Here.jpg → i_ll_just_wait_here.jpg
# I_love_the_smell_of_napalm_in_the_morning.jpg → i_love_the_smell_of_napalm_in_the_morning.jpg
# I_m_in_Danger___blank_place_above.jpg → i_m_in_danger_blank_place_above.jpg
# I_m_The_Captain_Now.jpg → i_m_the_captain_now.jpg
# I_m_tired_boss.jpg → i_m_tired_boss.jpg
# I_said_we_sad_today.jpg → i_said_we_sad_today.jpg
# I_See_Dead_People.jpg → i_see_dead_people.jpg
# I_Should_Buy_A_Boat_Cat.jpg → i_should_buy_a_boat_cat.jpg
# I_think_I_forgot_something.jpg → i_think_i_forgot_something.jpg
# I_think_i_might_miss_my_wife__blank_.jpg → i_think_i_might_miss_my_wife_blank.jpg
# I_ve_only_had_Arlo_for_a_day_and_a_half.jpg → i_ve_only_had_arlo_for_a_day_and_a_half.jpg
# I_Was_Told_There_Would_Be.jpg → i_was_told_there_would_be.jpg
# I_wish_all_x_a_very_y.jpg → i_wish_all_x_a_very_y.jpg
# Jack_Sparrow_Being_Chased.jpg → jack_sparrow_being_chased.jpg
# Jack_Torrance_axe_shining.jpg → jack_torrance_axe_shining.jpg
# James_Franco_First_Time.jpg → james_franco_first_time.jpg
# Jarvis_.jpg → jarvis.jpg
# Jarvis_Template.jpg → jarvis_template.jpg
# Jason_Momoa_Henry_Cavill_Meme.jpg → jason_momoa_henry_cavill_meme.jpg
# Jay_Inbetweeners_Completed_It.jpg → jay_inbetweeners_completed_it.jpg
# Jealous_Girlfriend.jpg → jealous_girlfriend.jpg
# Jesse_WTF_are_you_talking_about_.jpg → jesse_wtf_are_you_talking_about.jpg
# Jim_Halpert_Explains.jpg → jim_halpert_explains.jpg
# Jim_Halpert_Pointing_to_Whiteboard.jpg → jim_halpert_pointing_to_whiteboard.jpg
# John_Cena_confuses.jpg → john_cena_confuses.jpg
# John_Daly_and_Tiger_Woods.jpg → john_daly_and_tiger_woods.jpg
# Jojo_s_Walk.jpg → jojo_s_walk.jpg
# Judgemental_Volturi.jpg → judgemental_volturi.jpg
# Jump_on_Rake.jpg → jump_on_rake.jpg
# Keep_Calm_And_Carry_On_Red.jpg → keep_calm_and_carry_on_red.jpg
# Kermit_sipping_tea.jpg → kermit_sipping_tea.jpg
# Kirby_eating.jpg → kirby_eating.jpg
# Knights_of_the_Round_Table.jpg → knights_of_the_round_table.jpg
# Knight_with_arrow_in_helmet.jpg → knight_with_arrow_in_helmet.jpg
# Kombucha_Girl.jpg → kombucha_girl.jpg
# Kong_Godzilla_Doge.jpg → kong_godzilla_doge.jpg
# Kratos_and_my_life_is_yours.jpg → kratos_and_my_life_is_yours.jpg
# Kurt_Angle_Stare.jpg → kurt_angle_stare.jpg
# Kylo_Ren_MORE.jpg → kylo_ren_more.jpg
# Laughing_Leo.jpg → laughing_leo.jpg
# Laughing_Men_In_Suits.jpg → laughing_men_in_suits.jpg
# Laughing_wolf.jpg → laughing_wolf.jpg
# La_Roca__Ayer_Vino.jpg → la_roca_ayer_vino.jpg
# Lebron_James_Reportedly_forgot_to.jpg → lebron_james_reportedly_forgot_to.jpg
# Left_Exit_12_Off_Ramp.jpg → left_exit_12_off_ramp.jpg
# Leonardo_Dicaprio_Cheers.jpg → leonardo_dicaprio_cheers.jpg
# Leonardo_Dicaprio_pointing_at_tv.jpg → leonardo_dicaprio_pointing_at_tv.jpg
# Leonardo_DiCaprio_throwing_Money.jpg → leonardo_dicaprio_throwing_money.jpg
# Licking_lips.jpg → licking_lips.jpg
# Lion_king_yeet.jpg → lion_king_yeet.jpg
# Lisa_Simpson_s_Presentation.jpg → lisa_simpson_s_presentation.jpg
# Live_reaction.jpg → live_reaction.jpg
# Looks_like_meat_s_back_on_the_menu__boys_.jpg → looks_like_meat_s_back_on_the_menu_boys.jpg
# Look_At_Me.jpg → look_at_me.jpg
# Look_What_They_Need_To_Mimic_A_Fraction_Of_Our_Power.jpg → look_what_they_need_to_mimic_a_fraction_of_our_power.jpg
# Lord_of_the_Rings_Meat_s_back_on_the_menu.jpg → lord_of_the_rings_meat_s_back_on_the_menu.jpg
# madness___this_is_sparta.jpg → madness_this_is_sparta.jpg
# Mahatma_Gandhi_Rocks.jpg → mahatma_gandhi_rocks.jpg
# Make_your_own_meme.jpg → make_your_own_meme.jpg
# Manly_Handshake.jpg → manly_handshake.jpg
# Man_giving_sword_to_larger_man.jpg → man_giving_sword_to_larger_man.jpg
# Man_Holding_Cardboard_Sign.jpg → man_holding_cardboard_sign.jpg
# Marked_Safe_From.jpg → marked_safe_from.jpg
# Matrix_Morpheus.jpg → matrix_morpheus.jpg
# Maybe_i_am_a_monster_blank.jpg → maybe_i_am_a_monster_blank.jpg
# McDonald_s_Happy_Meal_Dance_Gif.jpg → mcdonald_s_happy_meal_dance_gif.jpg
# Mental_Gymnastics.jpg → mental_gymnastics.jpg
# Men_Discussing_Men_Fighting.jpg → men_discussing_men_fighting.jpg
# Metronome.jpg → metronome.jpg
# Me_And_The_Boys.jpg → me_and_the_boys.jpg
# Me_explaining_to_my_mom.jpg → me_explaining_to_my_mom.jpg
# Michael_Jackson_popcorn_gif.jpg → michael_jackson_popcorn_gif.jpg
# Midwit_memes.jpg → midwit_memes.jpg
# Milk_Girls.jpg → milk_girls.jpg
# Minion_in_dark_forest.jpg → minion_in_dark_forest.jpg
# Mocking_Spongebob.jpg → mocking_spongebob.jpg
# Moe_throws_Barney.jpg → moe_throws_barney.jpg
# Mom_can_we_have.jpg → mom_can_we_have.jpg
# Monkey_looking_away.jpg → monkey_looking_away.jpg
# Monkey_Puppet.jpg → monkey_puppet.jpg
# Monster_Inc__Walking.jpg → monster_inc_walking.jpg
# More_likely_than_you_think.jpg → more_likely_than_you_think.jpg
# Morgan_Freeman.jpg → morgan_freeman.jpg
# Mother_Ignoring_Kid_Drowning_In_A_Pool.jpg → mother_ignoring_kid_drowning_in_a_pool.jpg
# Mr_bean_copying.jpg → mr_bean_copying.jpg
# Mr_incredible_mad.jpg → mr_incredible_mad.jpg
# Mr_Krabs_Blur_Meme.jpg → mr_krabs_blur_meme.jpg
# Mr_T_Pity_The_Fool.jpg → mr_t_pity_the_fool.jpg
# Mr__McMahon_reaction.jpg → mr_mcmahon_reaction.jpg
# My_body_is_machine.jpg → my_body_is_machine.jpg
# My_child_will.jpg → my_child_will.jpg
# My_job_here_is_done.jpg → my_job_here_is_done.jpg
# Nah_I_d_Win.jpg → nah_i_d_win.jpg
# Nah_yeah.jpg → nah_yeah.jpg
# Narcos_waiting.jpg → narcos_waiting.jpg
# Naruto_Handshake_Meme_Template.jpg → naruto_handshake_meme_template.jpg
# Natalie_Portman.jpg → natalie_portman.jpg
# Needs_More_Cowbell.jpg → needs_more_cowbell.jpg
# Nemo_Seagulls_Mine.jpg → nemo_seagulls_mine.jpg
# Never_ask_a_woman_her_age.jpg → never_ask_a_woman_her_age.jpg
# Never_give_up.jpg → never_give_up.jpg
# News_Headline.jpg → news_headline.jpg
# Nick_Young.jpg → nick_young.jpg
# NONONOWAITWAITWAIT.jpg → nononowaitwaitwait.jpg
# Normal_and_dark_mr_incredibles.jpg → normal_and_dark_mr_incredibles.jpg
# Normal_Distribution_meme.jpg → normal_distribution_meme.jpg
# Note_passing.jpg → note_passing.jpg
# Not_sure_if__fry.jpg → not_sure_if_fry.jpg
# Now_That_s_What_I_Call.jpg → now_that_s_what_i_call.jpg
# No_Fear_One_Fear.jpg → no_fear_one_fear.jpg
# No_Soup_For_You.jpg → no_soup_for_you.jpg
# No_Take__Only_Throw.jpg → no_take_only_throw.jpg
# No_yes_lady.jpg → no_yes_lady.jpg
# No___Yes.jpg → no_yes.jpg
# NPC_Meme.jpg → npc_meme.jpg
# Nyan_Cat.jpg → nyan_cat.jpg
# Objects_in_mirror_are_closer_than_they_appear.jpg → objects_in_mirror_are_closer_than_they_appear.jpg
# Office_Space_Bill_Lumbergh.jpg → office_space_bill_lumbergh.jpg
# Oh_dear__dear_gorgeus.jpg → oh_dear_dear_gorgeus.jpg
# Oh_no_anyway.jpg → oh_no_anyway.jpg
# Oh_No_Black_Cat.jpg → oh_no_black_cat.jpg
# Oh_yeah__Oh_no___.jpg → oh_yeah_oh_no.jpg
# Ok_ima_fight.jpg → ok_ima_fight.jpg
# Old_man_cup_of_coffee.jpg → old_man_cup_of_coffee.jpg
# Old_man_yells_at_cloud.jpg → old_man_yells_at_cloud.jpg
# Oliver_Twist_Please_Sir.jpg → oliver_twist_please_sir.jpg
# Ol__Reliable.jpg → ol_reliable.jpg
# OMG_hi.jpg → omg_hi.jpg
# One_Does_Not_Simply.jpg → one_does_not_simply.jpg
# One_please.jpg → one_please.jpg
# Oops__All_Berries.jpg → oops_all_berries.jpg
# Oprah_You_Get_A.jpg → oprah_you_get_a.jpg
# Orangutan_chasing_girl_on_a_tricycle.jpg → orangutan_chasing_girl_on_a_tricycle.jpg
# Overly_Attached_Girlfriend.jpg → overly_attached_girlfriend.jpg
# Overwatch_Mercy_Meme.jpg → overwatch_mercy_meme.jpg
# Pablo_escobar_waiting_alone.jpg → pablo_escobar_waiting_alone.jpg
# Panik_Kalm_Panik.jpg → panik_kalm_panik.jpg
# Patrick_Dunk_Meme.jpg → patrick_dunk_meme.jpg
# PAtrick__Smart_Dumb.jpg → patrick_smart_dumb.jpg
# Paulo_Coelho.jpg → paulo_coelho.jpg
# Pawn_Stars_Best_I_Can_Do.jpg → pawn_stars_best_i_can_do.jpg
# Peace_sign_tombstone.jpg → peace_sign_tombstone.jpg
# Peasants.jpg → peasants.jpg
# Pedro_Pascal_crying.jpg → pedro_pascal_crying.jpg
# Pedro_Pascal_Nick_Cage.jpg → pedro_pascal_nick_cage.jpg
# Penguin_pointing_at_shipping_label.jpg → penguin_pointing_at_shipping_label.jpg
# Pepe_holding_sign.jpg → pepe_holding_sign.jpg
# Pepe_Silvia.jpg → pepe_silvia.jpg
# Pepe_the_Frog.jpg → pepe_the_frog.jpg
# Pepperidge_Farm_Remembers.jpg → pepperidge_farm_remembers.jpg
# Peter_Griffin_running_away.jpg → peter_griffin_running_away.jpg
# Peter_Griffin_skin_color_chart_race_terrorist_blank.jpg → peter_griffin_skin_color_chart_race_terrorist_blank.jpg
# Peter_parker_reading_a_book.jpg → peter_parker_reading_a_book.jpg
# Philosoraptor.jpg → philosoraptor.jpg
# Pie_Chart_Meme.jpg → pie_chart_meme.jpg
# Pinky_and_the_brain.jpg → pinky_and_the_brain.jpg
# Pink_Guy_vs_Bane.jpg → pink_guy_vs_bane.jpg
# Pippin_Second_Breakfast.jpg → pippin_second_breakfast.jpg
# Plague_Doctor_Gangsta_s_Paradise.jpg → plague_doctor_gangsta_s_paradise.jpg
# Plane_flying_from_explosions.jpg → plane_flying_from_explosions.jpg
# Please_sir_may_I_have_some_more.jpg → please_sir_may_i_have_some_more.jpg
# Pointing_mirror_guy.jpg → pointing_mirror_guy.jpg
# Poke_with_stick.jpg → poke_with_stick.jpg
# Por_que_tan_elegante_homero.jpg → por_que_tan_elegante_homero.jpg
# Predator_Handshake.jpg → predator_handshake.jpg
# Pretending_To_Be_Happy__Hiding_Crying_Behind_A_Mask.jpg → pretending_to_be_happy_hiding_crying_behind_a_mask.jpg
# Priest_tempted_by_girl.jpg → priest_tempted_by_girl.jpg
# Professor_Farnsworth_Good_News_Everyone.jpg → professor_farnsworth_good_news_everyone.jpg
# Protected_Kevin_Hart.jpg → protected_kevin_hart.jpg
# Prove_me_wrong.jpg → prove_me_wrong.jpg
# PTSD_Chihuahua.jpg → ptsd_chihuahua.jpg
# Puppet_hierarchy.jpg → puppet_hierarchy.jpg
# puppet_Monkey_looking_away.jpg → puppet_monkey_looking_away.jpg
# Put_It_Somewhere_Else_Patrick.jpg → put_it_somewhere_else_patrick.jpg
# Rage_Table_Smash.jpg → rage_table_smash.jpg
# Rainbow_Six___Fuze_The_Hostage.jpg → rainbow_six_fuze_the_hostage.jpg
# Reaction_Guys.jpg → reaction_guys.jpg
# Really__Right_in_front_of_my_pancit_.jpg → really_right_in_front_of_my_pancit.jpg
# Real_Shit.jpg → real_shit.jpg
# Red_Button_Hand.jpg → red_button_hand.jpg
# Red_pill_blue_pill.jpg → red_pill_blue_pill.jpg
# Relief.jpg → relief.jpg
# Rick_and_Carl.jpg → rick_and_carl.jpg
# Riley_Reid_meme.jpg → riley_reid_meme.jpg
# Robert_Downey_Jr_s_Comments.jpg → robert_downey_jr_s_comments.jpg
# Roblox_Ban.jpg → roblox_ban.jpg
# Robotnik_Button.jpg → robotnik_button.jpg
# Robotnik_Pressing_Red_Button.jpg → robotnik_pressing_red_button.jpg
# Roll_Safe_Think_About_It.jpg → roll_safe_think_about_it.jpg
# Ron_Swanson_trash_computer.jpg → ron_swanson_trash_computer.jpg
# Running_Away_Balloon.jpg → running_away_balloon.jpg
# Run_.jpg → run.jpg
# Sad_guy_Happy_guy_bus.jpg → sad_guy_happy_guy_bus.jpg
# Sad_Hamster.jpg → sad_hamster.jpg
# Sad_Pablo_Escobar.jpg → sad_pablo_escobar.jpg
# Samuel_L_Jackson_say_one_more_time.jpg → samuel_l_jackson_say_one_more_time.jpg
# Sarcastic_spongebob.jpg → sarcastic_spongebob.jpg
# Satisfied_Seal.jpg → satisfied_seal.jpg
# Say_it_Again__Dexter.jpg → say_it_again_dexter.jpg
# Say_That_Again_I_Dare_You.jpg → say_that_again_i_dare_you.jpg
# say_the_line_bart__simpsons.jpg → say_the_line_bart_simpsons.jpg
# Say_what_again.jpg → say_what_again.jpg
# Scared_Cat.jpg → scared_cat.jpg
# Scooby_doo_mask_reveal.jpg → scooby_doo_mask_reveal.jpg
# Scumbag_Steve.jpg → scumbag_steve.jpg
# Second_Breakfast.jpg → second_breakfast.jpg
# See_Nobody_Cares.jpg → see_nobody_cares.jpg
# Seinfeld_Newman.jpg → seinfeld_newman.jpg
# Severance_Outie_Affirmation.jpg → severance_outie_affirmation.jpg
# Show_me_on_this_doll.jpg → show_me_on_this_doll.jpg
# Shrek_Cat.jpg → shrek_cat.jpg
# Shrek_For_Five_Minutes.jpg → shrek_for_five_minutes.jpg
# Shrek_running.jpg → shrek_running.jpg
# Shut_Up_And_Take_My_Money_Fry.jpg → shut_up_and_take_my_money_fry.jpg
# Silence_Crab.jpg → silence_crab.jpg
# Silence_X__a_Y_is_talking.jpg → silence_x_a_y_is_talking.jpg
# Simpsons_bart_no.jpg → simpsons_bart_no.jpg
# Simpsons_Monkey_Fight.jpg → simpsons_monkey_fight.jpg
# Simpsons_so_far.jpg → simpsons_so_far.jpg
# Skeletor_until_we_meet_again.jpg → skeletor_until_we_meet_again.jpg
# Skinner_Out_Of_Touch.jpg → skinner_out_of_touch.jpg
# Sleeping_Shaq.jpg → sleeping_shaq.jpg
# sleeping_Squidward.jpg → sleeping_squidward.jpg
# Slowpoke.jpg → slowpoke.jpg
# Small_knight_giant_knight.jpg → small_knight_giant_knight.jpg
# Smart_Guy.jpg → smart_guy.jpg
# Smudge_the_cat.jpg → smudge_the_cat.jpg
# Soldiers_hold_up_society.jpg → soldiers_hold_up_society.jpg
# Somehow__Palpatine_returned_.jpg → somehow_palpatine_returned.jpg
# Sonic_Says.jpg → sonic_says.jpg
# South_Park_JIzz.jpg → south_park_jizz.jpg
# South_Park_Underpants_Gnomes.jpg → south_park_underpants_gnomes.jpg
# Soyboy_Vs_Yes_Chad.jpg → soyboy_vs_yes_chad.jpg
# Soyjak_Pointing.jpg → soyjak_pointing.jpg
# Sparta_Leonidas.jpg → sparta_leonidas.jpg
# Spiderman_Glasses.jpg → spiderman_glasses.jpg
# Spider_Man_Double.jpg → spider_man_double.jpg
# Spongebob_box.jpg → spongebob_box.jpg
# Spongebob_Ight_Imma_Head_Out.jpg → spongebob_ight_imma_head_out.jpg
# Spongebob_looking_out_window.jpg → spongebob_looking_out_window.jpg
# Spongebob_Searching.jpg → spongebob_searching.jpg
# Spongebob_time_card_background.jpg → spongebob_time_card_background.jpg
# Spongebob_Yelling.jpg → spongebob_yelling.jpg
# Spongegar.jpg → spongegar.jpg
# Squidward.jpg → squidward.jpg
# Squidward_chair.jpg → squidward_chair.jpg
# Squidward_competition.jpg → squidward_competition.jpg
# Squidward_pointing.jpg → squidward_pointing.jpg
# Squidward_window.jpg → squidward_window.jpg
# Squid_Game.jpg → squid_game.jpg
# Squid_Game__Season_1_vs_Season_2_.jpg → squid_game_season_1_vs_season_2.jpg
# Star_Wars_No.jpg → star_wars_no.jpg
# Star_Wars_Yoda.jpg → star_wars_yoda.jpg
# Steamboat_Willie.jpg → steamboat_willie.jpg
# Steve_Buscemi_Fellow_Kids.jpg → steve_buscemi_fellow_kids.jpg
# Stop_giving_me_your_toughest_battles.jpg → stop_giving_me_your_toughest_battles.jpg
# Stop_He_s_Already_Dead.jpg → stop_he_s_already_dead.jpg
# Stop_Trying_to_Make_Fetch_Happen.jpg → stop_trying_to_make_fetch_happen.jpg
# Straight_Outta_X_blank_template.jpg → straight_outta_x_blank_template.jpg
# Straight_to_Jail.jpg → straight_to_jail.jpg
# Strong_dog_vs_weak_dog.jpg → strong_dog_vs_weak_dog.jpg
# Stupid_dumb_drooling_puzzle.jpg → stupid_dumb_drooling_puzzle.jpg
# Success_Kid.jpg → success_kid.jpg
# Success_Kid_Original.jpg → success_kid_original.jpg
# Sun_Tzu.jpg → sun_tzu.jpg
# Superior_Royalty.jpg → superior_royalty.jpg
# Sure_grandma.jpg → sure_grandma.jpg
# Sure_grandma_let_s_get_you_to_bed.jpg → sure_grandma_let_s_get_you_to_bed.jpg
# Surprised_Joey.jpg → surprised_joey.jpg
# Surprised_Koala.jpg → surprised_koala.jpg
# Surprised_Pikachu.jpg → surprised_pikachu.jpg
# Surprised_Pikachu__High_Quality_.jpg → surprised_pikachu_high_quality.jpg
# Surprise_anime_guy.jpg → surprise_anime_guy.jpg
# Suspicious_Dog.jpg → suspicious_dog.jpg
# Sweating_Jordan_Peele.jpg → sweating_jordan_peele.jpg
# Sweaty_Speedrunner.jpg → sweaty_speedrunner.jpg
# Swerving_Car.jpg → swerving_car.jpg
# Symphony_Meme.jpg → symphony_meme.jpg
# Szia_uram__uncropped_.jpg → szia_uram_uncropped.jpg
# Teacher_s_Copy.jpg → teacher_s_copy.jpg
# Tell_me_the_truth__I_m_ready_to_hear_it.jpg → tell_me_the_truth_i_m_ready_to_hear_it.jpg
# Thank_you_for_saving_my_life.jpg → thank_you_for_saving_my_life.jpg
# Thanos_Infinity_Stones.jpg → thanos_infinity_stones.jpg
# That_s_a_paddlin_.jpg → that_s_a_paddlin.jpg
# That_s_how_you_do_it.jpg → that_s_how_you_do_it.jpg
# That_s_my_secret.jpg → that_s_my_secret.jpg
# That_s_the_neat_part__you_don_t.jpg → that_s_the_neat_part_you_don_t.jpg
# There_is_no_war_in_ba_sing_se.jpg → there_is_no_war_in_ba_sing_se.jpg
# These_Aren_t_The_Droids_You_Were_Looking_For.jpg → these_aren_t_the_droids_you_were_looking_for.jpg
# They_don_t_even_have_dental.jpg → they_don_t_even_have_dental.jpg
# They_don_t_know.jpg → they_don_t_know.jpg
# The_Cooler_Daniel.jpg → the_cooler_daniel.jpg
# The_future_world_if.jpg → the_future_world_if.jpg
# The_Most_Interesting_Man_In_The_World.jpg → the_most_interesting_man_in_the_world.jpg
# The_Simpsons_Ralph_Wiggum_Picking_His_Nose.jpg → the_simpsons_ralph_wiggum_picking_his_nose.jpg
# Thinking_Black_Guy.jpg → thinking_black_guy.jpg
# Think_Mark__Think.jpg → think_mark_think.jpg
# Third_World_Skeptical_Kid.jpg → third_world_skeptical_kid.jpg
# This_Is_Brilliant_But_I_Like_This.jpg → this_is_brilliant_but_i_like_this.jpg
# This_Is_Fine.jpg → this_is_fine.jpg
# This_is_Fine__Blank_.jpg → this_is_fine_blank.jpg
# This_is_sparta_.jpg → this_is_sparta.jpg
# This_Is_Where_I_d_Put_My_Trophy_If_I_Had_One.jpg → this_is_where_i_d_put_my_trophy_if_i_had_one.jpg
# This_is_Worthless.jpg → this_is_worthless.jpg
# Those_who_know.jpg → those_who_know.jpg
# Thousand_Yard_Stare.jpg → thousand_yard_stare.jpg
# Three_dragons.jpg → three_dragons.jpg
# Three_headed_Dragon.jpg → three_headed_dragon.jpg
# Tintin_and_Haddock.jpg → tintin_and_haddock.jpg
# Tom_chasing_Harry_and_Ron_Weasly.jpg → tom_chasing_harry_and_ron_weasly.jpg
# Tom___Jerry_Searching.jpg → tom_jerry_searching.jpg
# Tony_Soprano_in_this_house.jpg → tony_soprano_in_this_house.jpg
# Too_Damn_High.jpg → too_damn_high.jpg
# Tornado_Guy.jpg → tornado_guy.jpg
# TOYSTORY_EVERYWHERE.jpg → toystory_everywhere.jpg
# Trade_Offer.jpg → trade_offer.jpg
# Trade_offer_meme_Animated_gif.jpg → trade_offer_meme_animated_gif.jpg
# Traumatized_Mr__Incredible.jpg → traumatized_mr_incredible.jpg
# Travis_Kelce_screaming.jpg → travis_kelce_screaming.jpg
# Travolta.jpg → travolta.jpg
# Trojan_Horse.jpg → trojan_horse.jpg
# Trolley_Problem.jpg → trolley_problem.jpg
# Trumpet_Boy.jpg → trumpet_boy.jpg
# Trump_Bill_Signing.jpg → trump_bill_signing.jpg
# Trump_Executive_Order_2025.jpg → trump_executive_order_2025.jpg
# Trump__Vance__and_Zelensky.jpg → trump_vance_and_zelensky.jpg
# Tuxedo_Winnie_The_Pooh.jpg → tuxedo_winnie_the_pooh.jpg
# Tuxedo_Winnie_the_Pooh_grossed_reverse.jpg → tuxedo_winnie_the_pooh_grossed_reverse.jpg
# Twilight_Aro.jpg → twilight_aro.jpg
# Two_Buttons.jpg → two_buttons.jpg
# Two_guys_on_a_bus.jpg → two_guys_on_a_bus.jpg
# Two_Paths.jpg → two_paths.jpg
# Types_of_Headaches_meme.jpg → types_of_headaches_meme.jpg
# Typing_kitty.jpg → typing_kitty.jpg
# Tyrone_Biggums_The_Addict.jpg → tyrone_biggums_the_addict.jpg
# Uncanny_Pingu.jpg → uncanny_pingu.jpg
# Uncle_Sam.jpg → uncle_sam.jpg
# Undertaker_teleports_behind_AJ_Styles.jpg → undertaker_teleports_behind_aj_styles.jpg
# UNO_Draw_25_Cards.jpg → uno_draw_25_cards.jpg
# Unsettled_Tom.jpg → unsettled_tom.jpg
# Unsheathing_Sword.jpg → unsheathing_sword.jpg
# Urinal_Guy.jpg → urinal_guy.jpg
# Vanya_and_Five.jpg → vanya_and_five.jpg
# Vegeta_over_9000.jpg → vegeta_over_9000.jpg
# Vince_McMahon_Crying.jpg → vince_mcmahon_crying.jpg
# Virgin_and_Chad.jpg → virgin_and_chad.jpg
# Waiting_Skeleton.jpg → waiting_skeleton.jpg
# Wait__its_all.jpg → wait_its_all.jpg
# Walter_White_Breaks_Down.jpg → walter_white_breaks_down.jpg
# Walter_White_Screaming_At_Hank.jpg → walter_white_screaming_at_hank.jpg
# Water_Dam_Meme.jpg → water_dam_meme.jpg
# Weak_vs_Strong_Spongebob.jpg → weak_vs_strong_spongebob.jpg
# Welcome_To_The_Internets.jpg → welcome_to_the_internets.jpg
# We_are_not_the_same.jpg → we_are_not_the_same.jpg
# We_Have_A_Hulk.jpg → we_have_a_hulk.jpg
# Whatcha_Got_There_.jpg → whatcha_got_there.jpg
# What_did_it_cost_.jpg → what_did_it_cost.jpg
# What_Gives_People_Feelings_of_Power.jpg → what_gives_people_feelings_of_power.jpg
# What_if_i_told_you.jpg → what_if_i_told_you.jpg
# What_s_on_your_mind_.jpg → what_s_on_your_mind.jpg
# Who_Killed_Hannibal.jpg → who_killed_hannibal.jpg
# Who_wants_change.jpg → who_wants_change.jpg
# Why_Can_t_I_Hold_All_These_Limes.jpg → why_can_t_i_hold_all_these_limes.jpg
# Why_Can_t_You_Just_Be_Normal.jpg → why_can_t_you_just_be_normal.jpg
# Why_is_my_sister_s_name_Rose.jpg → why_is_my_sister_s_name_rose.jpg
# Why_would_they_do_this.jpg → why_would_they_do_this.jpg
# Why_you_no.jpg → why_you_no.jpg
# Will_Smith_punching_Chris_Rock.jpg → will_smith_punching_chris_rock.jpg
# Windows_Error_Message.jpg → windows_error_message.jpg
# Winter_Is_Coming.jpg → winter_is_coming.jpg
# Wolverine_Remember.jpg → wolverine_remember.jpg
# Woman_Shouting_Knives.jpg → woman_shouting_knives.jpg
# Woman_Yelling_At_Cat.jpg → woman_yelling_at_cat.jpg
# Won_t_somebody_think_of_the_children.jpg → won_t_somebody_think_of_the_children.jpg
# Woody_and_Buzz_Lightyear_Everywhere_Widescreen.jpg → woody_and_buzz_lightyear_everywhere_widescreen.jpg
# Worst_day_of_my_life.jpg → worst_day_of_my_life.jpg
# Worst_mistake_of_my_life.jpg → worst_mistake_of_my_life.jpg
# Xbox_Achievement.jpg → xbox_achievement.jpg
# X_All_The_Y.jpg → x_all_the_y.jpg
# X_but_Y.jpg → x_but_y.jpg
# Yelling_Beaver.jpg → yelling_beaver.jpg
# Yes_Dear.jpg → yes_dear.jpg
# Yhorm_Dark_Souls.jpg → yhorm_dark_souls.jpg
# Yoda_Begun_The_Clone_War_Has.jpg → yoda_begun_the_clone_war_has.jpg
# Young_Thug_and_Lil_Durk_troubleshooting.jpg → young_thug_and_lil_durk_troubleshooting.jpg
# You_can_excuse_racism__blank_.jpg → you_can_excuse_racism_blank.jpg
# You_Guys_always_act_like_you_re_better_than_me.jpg → you_guys_always_act_like_you_re_better_than_me.jpg
# You_Guys_are_Getting_Paid.jpg → you_guys_are_getting_paid.jpg
# You_know__I_m_something_of_a_scientist_myself.jpg → you_know_i_m_something_of_a_scientist_myself.jpg
# You_Merely_Adopted_X_I_Was_Born_In_It_Molded_By_It.jpg → you_merely_adopted_x_i_was_born_in_it_molded_by_it.jpg
# You_re_a_wizard_harry.jpg → you_re_a_wizard_harry.jpg
# You_re_laughing_.jpg → you_re_laughing.jpg
# You_Should_Feel_Bad_Zoidberg.jpg → you_should_feel_bad_zoidberg.jpg
# You_Were_The_Chosen_One__Star_Wars_.jpg → you_were_the_chosen_one_star_wars.jpg
# You_wouldn_t_X_a_Y.jpg → you_wouldn_t_x_a_y.jpg
# Yo_Dawg_Heard_You.jpg → yo_dawg_heard_you.jpg
# Yu_Gi_Oh_Dramatic_Crossroads.jpg → yu_gi_oh_dramatic_crossroads.jpg
# Y_all_Got_Any_More_Of_That.jpg → y_all_got_any_more_of_that.jpg
# Y_U_No.jpg → y_u_no.jpg
# Zombieland_money_tears.jpg → zombieland_money_tears.jpg
# Zoolander_Stare_TT.jpg → zoolander_stare_tt.jpg
# _We_did_it__Patrick__We_saved_the_City__.jpg → we_did_it_patrick_we_saved_the_city.jpg
